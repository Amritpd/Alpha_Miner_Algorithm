# %%
! pip install pygame
# Out:
# Collecting pygame
#   Downloading https://files.pythonhosted.org/packages/45/34/38e7465c1aea7d570b83d9004eb0c4e783c9c1b17eb9eeb9a760c0898783/pygame-1.9.4-cp36-cp36m-win_amd64.whl (4.2MB)
# Installing collected packages: pygame
# Successfully installed pygame-1.9.4

# %%
! pip install SNAKES
# Out:
# Collecting SNAKES
#   Downloading https://files.pythonhosted.org/packages/39/d6/49a449988b52810df7bb71afde4171540d8a1f69ebc923abe92f6e27fea3/SNAKES-0.9.26.tar.gz (679kB)
# Building wheels for collected packages: SNAKES
#   Running setup.py bdist_wheel for SNAKES: started
#   Running setup.py bdist_wheel for SNAKES: finished with status 'done'
#   Stored in directory: C:\Users\secon\AppData\Local\pip\Cache\wheels\78\34\78\bbbed1d71434c74daa63756827b6c0cdf0733877f50cd4d7c0
# Successfully built SNAKES
# Installing collected packages: SNAKES
# Successfully installed SNAKES-0.9.26

# %%
#import
import sys
from enum import Enum
import itertools
import pygame
import snakes.plugins
from sortedcontainers import SortedList, SortedSet, SortedDict
import collections
snakes.plugins.load('gv', 'snakes.nets', 'nets')
from nets import *
# just for the notebook
from IPython.display import Image
import pandas as pd

import os
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %% [raw]
# # class that represent relation between transitions
# (causality , succession , right causality , left causality , parallel , choices)

# %%
class Relations(Enum):
	SUCCESSIONS     = '>'
	RIGHT_CAUSALITY = '->'
	LEFT_CAUSALITY  = '<-'
	PARALLEL        = '||'
	CHOICES         = '#'

# %%
# class representing Alpha miner
# Alpha Miner class
class AlphaMiner:

	def __init__(self,Traces):
		# Traces within an event log
		self.traces = Traces
		# set of transition a.k.a activities or T
		self.transitions = SortedSet()
		# set of initial transitions Ti
		self.initial_transitions = SortedSet()
		# set of final transitions To
		self.final_transitions = SortedSet()
		# set of pairs (A,B)  Xl
		self.pairs = []
		# set of maximal pairs (A,B) Yl
		self.maxi_pairs = []
		# set of p(A,B) between maxi_pairs Pl
		self.places = []
		# Footprint , relations between activities
		self.relations = SortedDict()
		#Petri NET
		self.PetriNet = None
	def getTransitions(self):
		#Lemme 1
		for trace in self.traces.values():
			for activity in trace:
				self.transitions.add(activity)
		return self.transitions
	def getInitialTransitions(self):
		# Lemme 2
		#For each trace get the first activity 
		#and add it to a set of initial transitions
		for trace in self.traces.values():
			print(trace[0])
			self.initial_transitions.add(trace[0])
		return self.initial_transitions;
	def getFinalTransitions(self):
		#For each trace get the first activity 
		#and add it to a set of initial transitions
		for trace in self.traces.values():
			print(trace[len(trace)-1])
			self.final_transitions.add(trace[len(trace)-1])
		return self.final_transitions
		
	def extractRelations(self):
		
		

		#Extract non repetitive traces, alpha dont take care  about  frequencies !
		nnrep_traces = SortedSet()
		for trace in self.traces.values():
			nnrep_traces.add("".join(trace))
		print(nnrep_traces)
		#Extract relations between each transitions
		# generate Footprint
		for transition1 in self.transitions:
			self.relations[transition1] = SortedDict()
			for transition2 in self.transitions:
				concat = transition1+transition2
				print(concat)
				relation = None
				for trace in nnrep_traces:
					
					if trace.find(concat) >= 0:
						#Causality
						print(concat)
						if  relation == Relations.LEFT_CAUSALITY:
							relation = Relations.PARALLEL
						else:
							relation = Relations.RIGHT_CAUSALITY

					if trace.find(concat[::-1]) >= 0:
						print(concat[::-1])
						if relation == Relations.RIGHT_CAUSALITY:
							relation = Relations.PARALLEL
						else:
							relation = Relations.LEFT_CAUSALITY
				if relation == None:
					relation = Relations.CHOICES
				self.relations[transition1][transition2] = relation


		return self.relations
	def computePairs(self):
		# extract pairs of set , each set contain activities 
		#that doesnt have any relation between them and the activities in the two set have to be direcly successed by each other 
		#Lemme 4
	    pairs_causality = []
	    pairs_choices = []
	    pairs = []
	    #Extract all possible pairs of activity with causality relation
	    for activity1 ,relations1 in self.relations.items():
	    	for activity2 , relation in relations1.items():
	    		if relation == Relations.RIGHT_CAUSALITY :
	    			pairs_causality.append((activity1,activity2))
	    		if relation == Relations.CHOICES:
	    			if activity1 == activity2:
	    				pairs_choices.append((activity1,))
	    			else:
	    				pairs_choices.append((activity1,activity2))

	    print(pairs_causality)
	    pairs= pairs_causality
	    print(pairs_choices)

	    #  find all possible sets of activity with causality relation
	    #  
	    i = 0
	    j = len(pairs_choices)

	    while i < j :
	    	seti = pairs_choices[i]
	    	for pair in pairs_choices:
	    		union = True
	    		if len(SortedSet(seti).intersection(SortedSet(pair))) != 0:
	    			for e1 in pair:
	    				if union == False:
	    					break
	    				for e2 in seti:
	    					if self.relations[e1][e2] != Relations.CHOICES:
	    						union = False
	    						break
	    			if union :
	    				new_pair = SortedSet(seti) | SortedSet(pair) 
	    				if tuple(new_pair) not in pairs_choices:
	    					pairs_choices.append(tuple(new_pair))
	    					j = j + 1
	    					#Reevaluate the length
	    		
	    	i = i + 1

	    print(pairs_choices)

	    # Union 
	    for pair_choices1 in pairs_choices:
	    	for pair_choices2 in pairs_choices:
	    		relation_between_pair = None
	    		makePair = True
	    		print("pair 1",pair_choices1)
	    		print("pair 2",pair_choices2)
	    		intersection = SortedSet(pair_choices1).intersection(pair_choices2)
	    		pair_choices2 = SortedSet(pair_choices2)
	    		if len(intersection) != 0 :
	    			# remove intersection terms in the second pair
	    			for term in intersection:
	    				pair_choices2.discard(term)
                  
	    		if(len(pair_choices2) == 0):
	    			continue
	    		pair_choices2= tuple(pair_choices2)
	    		print("pair_choices2 with discarded term :",pair_choices2)

	    		for activity1 in pair_choices1:
	    			print(activity1)
	    			if makePair == False:
	    				break
	    			for activity2 in pair_choices2:
	    				print(activity2)
	    				relation = self.relations[activity1][activity2]
	    				if relation_between_pair != None and relation_between_pair != relation:
	    					makePair = False
	    					break
	    				else:
	    					relation_between_pair = relation
	    				if relation != Relations.RIGHT_CAUSALITY:
	    					makePair = False
	    					break
	    		if makePair == True:
	    			print("makepair true")
	    			print(pair_choices1)
	    			print(pair_choices2)
	    			if relation_between_pair == Relations.RIGHT_CAUSALITY:
	    				new_pair = (pair_choices1,pair_choices2)
	    			else:
	    				new_pair = (pair_choices2,pair_choices1)
	    			pairs.append(new_pair)
	    print("\n")
	    print("\n")
	    print(pairs)
	    self.pairs = pairs



	    		

	    '''
		combinations = list(itertools.combinations(list(self.transitions),len(self.transitions)))
		possible_successions = SortedSet() 
		for combination in combinations:
			combination = "".join(combination)
			possible_successions.add(combination)
		print(possible_successions)'''

	def extract_maximal_pairs(self):
		pos1 =0
		pair_appended = []
		maxi_pairs = []
		for pair1 in self.pairs:
			append = True
			# flat the pair 1
			flat_pair1 = []
			for s in pair1:
				for e in s:
					flat_pair1.append(e)
			print("pair1 :",pair1)
			print("flat_pair1 :",flat_pair1)
			pos2 = 0
			for pair2 in self.pairs:
				if pos1 != pos2:
					flat_pair2 = []
					for s in pair2:
						for e in s:
							flat_pair2.append(e)
					print("pair2 :",pair2)
					print("flat_pair2 :",flat_pair2)
					# flat the pair 1

					# flat the pair 2
					# check if pair1 issubset of pair 2 or pair 2 is subset of 1
					if SortedSet(flat_pair1).issubset(flat_pair2) and SortedSet(flat_pair1)!= SortedSet(flat_pair2):
						print("issubset")
						append = False
				pos2 = pos2 + 1

			if append == True:

				print("append")
				if SortedSet(flat_pair1) not in pair_appended:
					maxi_pairs.append(pair1)
					pair_appended.append(SortedSet(flat_pair1))
			pos1 = pos1 + 1
		print(maxi_pairs)
		self.maxi_pairs = maxi_pairs



		#Lemme 5
		pass
	def add_places(self):
		#Lemme 6

		# connect initial transition with place
		cpt = 0
		self.places.append(("P"+str(cpt),self.initial_transitions))
		cpt = 1  
		for pair in self.maxi_pairs:
			self.places.append((pair[0],"P"+str(cpt),pair[1]))
			cpt+=1
		self.places.append((self.final_transitions,"P"+str(cpt)))
		print(self.places)

	def extract_PetriNet(self):
		n = PetriNet('N')
		n.add_place(Place('p'+str(0)))
		cpt_p = 1
		for pair in self.maxi_pairs:
			n.add_place(Place('p'+str(cpt_p)))
			cpt_p += 1
		n.add_place(Place('p'+str(cpt_p)))
		for transition in self.transitions:
			n.add_transition(Transition(transition))
		print(self.initial_transitions)
		for transition in self.initial_transitions:
			n.add_input('p'+str(0),transition,Value(dot))
		cpt_p = 1
		for pair in self.maxi_pairs:
			#pair[0] produce
			#pair[1] consume
			for transition in pair[0]:
				n.add_output('p'+str(cpt_p), transition,Value(dot))
			for transition in pair[1]:
				n.add_input('p'+str(cpt_p), transition,Value(dot))
			cpt_p+=1
		for transition in self.final_transitions:
			n.add_output('p'+str(cpt_p),transition,Value(dot))
		self.PetriNet = n

	def show(self,model = None):

			def draw_place (place, attr) :
				attr['label'] = place.name.upper()
				attr['color'] = '#FF0000'
			def draw_transition (trans, attr) :
				if str(trans.guard) == 'True' :
					attr['label'] = trans.name
				else :
					attr['label'] = '%s\n%s' % (trans.name, trans.guard)
			self.PetriNet.draw('C:/Users/secon/Documents/Learning-projects/modules/,net-with-colors.png',place_attr=draw_place, trans_attr=draw_transition)
			import pygame 
			pygame.init()

			size = width, height = 1200, 682
			WHITE = (255, 255, 255)


			screen = pygame.display.set_mode(size)
			screen.fill(WHITE)
			pygame.display.set_caption("petri net alphaminer")

			petri_net = pygame.image.load("C:/Users/secon/Documents/Learning-projects/modules/,net-with-colors.png").convert()
			surf = pygame.transform.rotate(petri_net, 90)
			screen.blit(surf, (50, 0))

			pygame.display.flip()
			while True:
				for e in pygame.event.get():
					if e.type == pygame.QUIT or (e.type == pygame.KEYDOWN and e.key == pygame.K_ESCAPE):
						done = True
						break

# %%
# testing
with open("Bonus_log.csv","r") as my_file :
	traces = SortedDict()
	contenu = my_file.read()
	events = contenu.splitlines()#contenu.split("\n") 

	for event in events:
		print(event)
		case_id,activity = event.split(',')
		if case_id not in traces:
			traces[case_id] = []

		traces[case_id].append(activity)
	print(traces)
# Out:
# case,activity
# 1,A
# 1,B
# 1,C
# 2,A
# 2,D
# 2,C
# 3,A
# 3,E
# 3,F
# 3,H
# 4,A
# 4,E
# 4,G
# 4,H
# 5,A
# 5,C
# 5,B
# 6,A
# 6,C
# 6,D
# 7,A
# 7,F
# 8,A
# 8,E
# 8,F
# 9,A
# 9,E
# 9,F
# 10,A
# 10,H
# 10,F
# 11,A
# 11,B
# 11,B
# 11,C
# 12,A
# 12,D
# 12,C
# 12,C
# 13,A
# 13,B
# 13,C
# 13,B
# 13,C
# SortedDict(None, 1000, {'1': ['A', 'B', 'C'], '10': ['A', 'H', 'F'], '11': ['A', 'B', 'B', 'C'], '12': ['A', 'D', 'C', 'C'], '13': ['A', 'B', 'C', 'B', 'C'], '2': ['A', 'D', 'C'], '3': ['A', 'E', 'F', 'H'], '4': ['A', 'E', 'G', 'H'], '5': ['A', 'C', 'B'], '6': ['A', 'C', 'D'], '7': ['A', 'F'], '8': ['A', 'E', 'F'], '9': ['A', 'E', 'F'], 'case': ['activity']})

# %%
Alph = AlphaMiner(traces)

Alph.getInitialTransitions()
Alph.getFinalTransitions()
Alph.getTransitions()
Alph.extractRelations()

Alph.computePairs()
Alph.extract_maximal_pairs()
Alph.add_places()
# Out:
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# activity
# C
# F
# C
# C
# C
# C
# H
# H
# B
# D
# F
# F
# F
# activity
# SortedSet(['ABBC', 'ABC', 'ABCBC', 'ACB', 'ACD', 'ADC', 'ADCC', 'AEF', 'AEFH', 'AEGH', 'AF', 'AHF', 'activity'], key=None, load=1000)
# AA
# AB
# AB
# AB
# AB
# AC
# AC
# AC
# AD
# AD
# AD
# AE
# AE
# AE
# AE
# AF
# AF
# AG
# AH
# AH
# Aactivity
# BA
# AB
# AB
# AB
# BB
# BB
# BB
# BC
# BC
# BC
# BC
# CB
# CB
# BD
# BE
# BF
# BG
# BH
# Bactivity
# CA
# AC
# AC
# CB
# BC
# BC
# CB
# BC
# CB
# CC
# CC
# CC
# CD
# CD
# DC
# DC
# CE
# CF
# CG
# CH
# Cactivity
# DA
# AD
# AD
# DB
# DC
# CD
# DC
# DC
# DD
# DE
# DF
# DG
# DH
# Dactivity
# EA
# AE
# AE
# AE
# EB
# EC
# ED
# EE
# EF
# EF
# EF
# EG
# EG
# EH
# Eactivity
# FA
# AF
# FB
# FC
# FD
# FE
# EF
# EF
# FF
# FG
# FH
# FH
# HF
# Factivity
# GA
# GB
# GC
# GD
# GE
# EG
# GF
# GG
# GH
# GH
# Gactivity
# HA
# AH
# HB
# HC
# HD
# HE
# HF
# FH
# HF
# HG
# GH
# HH
# Hactivity
# activityA
# activityB
# activityC
# activityD
# activityE
# activityF
# activityG
# activityH
# activityactivity
# [('A', 'B'), ('A', 'C'), ('A', 'D'), ('A', 'E'), ('A', 'F'), ('A', 'H'), ('D', 'C'), ('E', 'F'), ('E', 'G'), ('G', 'H')]
# [('A',), ('A', 'G'), ('A', 'activity'), ('B', 'D'), ('B', 'E'), ('B', 'F'), ('B', 'G'), ('B', 'H'), ('B', 'activity'), ('C', 'E'), ('C', 'F'), ('C', 'G'), ('C', 'H'), ('C', 'activity'), ('D', 'B'), ('D',), ('D', 'E'), ('D', 'F'), ('D', 'G'), ('D', 'H'), ('D', 'activity'), ('E', 'B'), ('E', 'C'), ('E', 'D'), ('E',), ('E', 'H'), ('E', 'activity'), ('F', 'B'), ('F', 'C'), ('F', 'D'), ('F',), ('F', 'G'), ('F', 'activity'), ('G', 'A'), ('G', 'B'), ('G', 'C'), ('G', 'D'), ('G', 'F'), ('G',), ('G', 'activity'), ('H', 'B'), ('H', 'C'), ('H', 'D'), ('H', 'E'), ('H',), ('H', 'activity'), ('activity', 'A'), ('activity', 'B'), ('activity', 'C'), ('activity', 'D'), ('activity', 'E'), ('activity', 'F'), ('activity', 'G'), ('activity', 'H'), ('activity',)]
# [('A',), ('A', 'G'), ('A', 'activity'), ('B', 'D'), ('B', 'E'), ('B', 'F'), ('B', 'G'), ('B', 'H'), ('B', 'activity'), ('C', 'E'), ('C', 'F'), ('C', 'G'), ('C', 'H'), ('C', 'activity'), ('D', 'B'), ('D',), ('D', 'E'), ('D', 'F'), ('D', 'G'), ('D', 'H'), ('D', 'activity'), ('E', 'B'), ('E', 'C'), ('E', 'D'), ('E',), ('E', 'H'), ('E', 'activity'), ('F', 'B'), ('F', 'C'), ('F', 'D'), ('F',), ('F', 'G'), ('F', 'activity'), ('G', 'A'), ('G', 'B'), ('G', 'C'), ('G', 'D'), ('G', 'F'), ('G',), ('G', 'activity'), ('H', 'B'), ('H', 'C'), ('H', 'D'), ('H', 'E'), ('H',), ('H', 'activity'), ('activity', 'A'), ('activity', 'B'), ('activity', 'C'), ('activity', 'D'), ('activity', 'E'), ('activity', 'F'), ('activity', 'G'), ('activity', 'H'), ('activity',), ('A', 'G', 'activity'), ('B', 'D', 'E'), ('B', 'D', 'F'), ('B', 'D', 'G'), ('B', 'D', 'H'), ('B', 'D', 'activity'), ('B', 'E', 'H'), ('B', 'E', 'activity'), ('B', 'F', 'G'), ('B', 'F', 'activity'), ('B', 'G', 'activity'), ('B', 'H', 'activity'), ('C', 'E', 'H'), ('C', 'E', 'activity'), ('C', 'F', 'G'), ('C', 'F', 'activity'), ('C', 'G', 'activity'), ('C', 'H', 'activity'), ('D', 'E', 'H'), ('D', 'E', 'activity'), ('B', 'D', 'E', 'H'), ('B', 'D', 'E', 'activity'), ('D', 'F', 'G'), ('D', 'F', 'activity'), ('B', 'D', 'F', 'G'), ('B', 'D', 'F', 'activity'), ('D', 'G', 'activity'), ('B', 'D', 'G', 'activity'), ('D', 'F', 'G', 'activity'), ('B', 'D', 'F', 'G', 'activity'), ('D', 'H', 'activity'), ('B', 'D', 'H', 'activity'), ('D', 'E', 'H', 'activity'), ('B', 'D', 'E', 'H', 'activity'), ('E', 'H', 'activity'), ('B', 'E', 'H', 'activity'), ('C', 'E', 'H', 'activity'), ('F', 'G', 'activity'), ('B', 'F', 'G', 'activity'), ('C', 'F', 'G', 'activity')]
# pair 1 ('A',)
# pair 2 ('A',)
# pair 1 ('A',)
# pair 2 ('A', 'G')
# pair_choices2 with discarded term : ('G',)
# A
# G
# pair 1 ('A',)
# pair 2 ('A', 'activity')
# pair_choices2 with discarded term : ('activity',)
# A
# activity
# pair 1 ('A',)
# pair 2 ('B', 'D')
# pair_choices2 with discarded term : ('B', 'D')
# A
# B
# D
# makepair true
# ('A',)
# ('B', 'D')
# pair 1 ('A',)
# pair 2 ('B', 'E')
# pair_choices2 with discarded term : ('B', 'E')
# A
# B
# E
# makepair true
# ('A',)
# ('B', 'E')
# pair 1 ('A',)
# pair 2 ('B', 'F')
# pair_choices2 with discarded term : ('B', 'F')
# A
# B
# F
# makepair true
# ('A',)
# ('B', 'F')
# pair 1 ('A',)
# pair 2 ('B', 'G')
# pair_choices2 with discarded term : ('B', 'G')
# A
# B
# G
# pair 1 ('A',)
# pair 2 ('B', 'H')
# pair_choices2 with discarded term : ('B', 'H')
# A
# B
# H
# makepair true
# ('A',)
# ('B', 'H')
# pair 1 ('A',)
# pair 2 ('B', 'activity')
# pair_choices2 with discarded term : ('B', 'activity')
# A
# B
# activity
# pair 1 ('A',)
# pair 2 ('C', 'E')
# pair_choices2 with discarded term : ('C', 'E')
# A
# C
# E
# makepair true
# ('A',)
# ('C', 'E')
# pair 1 ('A',)
# pair 2 ('C', 'F')
# pair_choices2 with discarded term : ('C', 'F')
# A
# C
# F
# makepair true
# ('A',)
# ('C', 'F')
# pair 1 ('A',)
# pair 2 ('C', 'G')
# pair_choices2 with discarded term : ('C', 'G')
# A
# C
# G
# pair 1 ('A',)
# pair 2 ('C', 'H')
# pair_choices2 with discarded term : ('C', 'H')
# A
# C
# H
# makepair true
# ('A',)
# ('C', 'H')
# pair 1 ('A',)
# pair 2 ('C', 'activity')
# pair_choices2 with discarded term : ('C', 'activity')
# A
# C
# activity
# pair 1 ('A',)
# pair 2 ('D', 'B')
# pair_choices2 with discarded term : ('B', 'D')
# A
# B
# D
# makepair true
# ('A',)
# ('B', 'D')
# pair 1 ('A',)
# pair 2 ('D',)
# pair_choices2 with discarded term : ('D',)
# A
# D
# makepair true
# ('A',)
# ('D',)
# pair 1 ('A',)
# pair 2 ('D', 'E')
# pair_choices2 with discarded term : ('D', 'E')
# A
# D
# E
# makepair true
# ('A',)
# ('D', 'E')
# pair 1 ('A',)
# pair 2 ('D', 'F')
# pair_choices2 with discarded term : ('D', 'F')
# A
# D
# F
# makepair true
# ('A',)
# ('D', 'F')
# pair 1 ('A',)
# pair 2 ('D', 'G')
# pair_choices2 with discarded term : ('D', 'G')
# A
# D
# G
# pair 1 ('A',)
# pair 2 ('D', 'H')
# pair_choices2 with discarded term : ('D', 'H')
# A
# D
# H
# makepair true
# ('A',)
# ('D', 'H')
# pair 1 ('A',)
# pair 2 ('D', 'activity')
# pair_choices2 with discarded term : ('D', 'activity')
# A
# D
# activity
# pair 1 ('A',)
# pair 2 ('E', 'B')
# pair_choices2 with discarded term : ('B', 'E')
# A
# B
# E
# makepair true
# ('A',)
# ('B', 'E')
# pair 1 ('A',)
# pair 2 ('E', 'C')
# pair_choices2 with discarded term : ('C', 'E')
# A
# C
# E
# makepair true
# ('A',)
# ('C', 'E')
# pair 1 ('A',)
# pair 2 ('E', 'D')
# pair_choices2 with discarded term : ('D', 'E')
# A
# D
# E
# makepair true
# ('A',)
# ('D', 'E')
# pair 1 ('A',)
# pair 2 ('E',)
# pair_choices2 with discarded term : ('E',)
# A
# E
# makepair true
# ('A',)
# ('E',)
# pair 1 ('A',)
# pair 2 ('E', 'H')
# pair_choices2 with discarded term : ('E', 'H')
# A
# E
# H
# makepair true
# ('A',)
# ('E', 'H')
# pair 1 ('A',)
# pair 2 ('E', 'activity')
# pair_choices2 with discarded term : ('E', 'activity')
# A
# E
# activity
# pair 1 ('A',)
# pair 2 ('F', 'B')
# pair_choices2 with discarded term : ('B', 'F')
# A
# B
# F
# makepair true
# ('A',)
# ('B', 'F')
# pair 1 ('A',)
# pair 2 ('F', 'C')
# pair_choices2 with discarded term : ('C', 'F')
# A
# C
# F
# makepair true
# ('A',)
# ('C', 'F')
# pair 1 ('A',)
# pair 2 ('F', 'D')
# pair_choices2 with discarded term : ('D', 'F')
# A
# D
# F
# makepair true
# ('A',)
# ('D', 'F')
# pair 1 ('A',)
# pair 2 ('F',)
# pair_choices2 with discarded term : ('F',)
# A
# F
# makepair true
# ('A',)
# ('F',)
# pair 1 ('A',)
# pair 2 ('F', 'G')
# pair_choices2 with discarded term : ('F', 'G')
# A
# F
# G
# pair 1 ('A',)
# pair 2 ('F', 'activity')
# pair_choices2 with discarded term : ('F', 'activity')
# A
# F
# activity
# pair 1 ('A',)
# pair 2 ('G', 'A')
# pair_choices2 with discarded term : ('G',)
# A
# G
# pair 1 ('A',)
# pair 2 ('G', 'B')
# pair_choices2 with discarded term : ('B', 'G')
# A
# B
# G
# pair 1 ('A',)
# pair 2 ('G', 'C')
# pair_choices2 with discarded term : ('C', 'G')
# A
# C
# G
# pair 1 ('A',)
# pair 2 ('G', 'D')
# pair_choices2 with discarded term : ('D', 'G')
# A
# D
# G
# pair 1 ('A',)
# pair 2 ('G', 'F')
# pair_choices2 with discarded term : ('F', 'G')
# A
# F
# G
# pair 1 ('A',)
# pair 2 ('G',)
# pair_choices2 with discarded term : ('G',)
# A
# G
# pair 1 ('A',)
# pair 2 ('G', 'activity')
# pair_choices2 with discarded term : ('G', 'activity')
# A
# G
# pair 1 ('A',)
# pair 2 ('H', 'B')
# pair_choices2 with discarded term : ('B', 'H')
# A
# B
# H
# makepair true
# ('A',)
# ('B', 'H')
# pair 1 ('A',)
# pair 2 ('H', 'C')
# pair_choices2 with discarded term : ('C', 'H')
# A
# C
# H
# makepair true
# ('A',)
# ('C', 'H')
# pair 1 ('A',)
# pair 2 ('H', 'D')
# pair_choices2 with discarded term : ('D', 'H')
# A
# D
# H
# makepair true
# ('A',)
# ('D', 'H')
# pair 1 ('A',)
# pair 2 ('H', 'E')
# pair_choices2 with discarded term : ('E', 'H')
# A
# E
# H
# makepair true
# ('A',)
# ('E', 'H')
# pair 1 ('A',)
# pair 2 ('H',)
# pair_choices2 with discarded term : ('H',)
# A
# H
# makepair true
# ('A',)
# ('H',)
# pair 1 ('A',)
# pair 2 ('H', 'activity')
# pair_choices2 with discarded term : ('H', 'activity')
# A
# H
# activity
# pair 1 ('A',)
# pair 2 ('activity', 'A')
# pair_choices2 with discarded term : ('activity',)
# A
# activity
# pair 1 ('A',)
# pair 2 ('activity', 'B')
# pair_choices2 with discarded term : ('B', 'activity')
# A
# B
# activity
# pair 1 ('A',)
# pair 2 ('activity', 'C')
# pair_choices2 with discarded term : ('C', 'activity')
# A
# C
# activity
# pair 1 ('A',)
# pair 2 ('activity', 'D')
# pair_choices2 with discarded term : ('D', 'activity')
# A
# D
# activity
# pair 1 ('A',)
# pair 2 ('activity', 'E')
# pair_choices2 with discarded term : ('E', 'activity')
# A
# E
# activity
# pair 1 ('A',)
# pair 2 ('activity', 'F')
# pair_choices2 with discarded term : ('F', 'activity')
# A
# F
# activity
# pair 1 ('A',)
# pair 2 ('activity', 'G')
# pair_choices2 with discarded term : ('G', 'activity')
# A
# G
# pair 1 ('A',)
# pair 2 ('activity', 'H')
# pair_choices2 with discarded term : ('H', 'activity')
# A
# H
# activity
# pair 1 ('A',)
# pair 2 ('activity',)
# pair_choices2 with discarded term : ('activity',)
# A
# activity
# pair 1 ('A',)
# pair 2 ('A', 'G', 'activity')
# pair_choices2 with discarded term : ('G', 'activity')
# A
# G
# pair 1 ('A',)
# pair 2 ('B', 'D', 'E')
# pair_choices2 with discarded term : ('B', 'D', 'E')
# A
# B
# D
# E
# makepair true
# ('A',)
# ('B', 'D', 'E')
# pair 1 ('A',)
# pair 2 ('B', 'D', 'F')
# pair_choices2 with discarded term : ('B', 'D', 'F')
# A
# B
# D
# F
# makepair true
# ('A',)
# ('B', 'D', 'F')
# pair 1 ('A',)
# pair 2 ('B', 'D', 'G')
# pair_choices2 with discarded term : ('B', 'D', 'G')
# A
# B
# D
# G
# pair 1 ('A',)
# pair 2 ('B', 'D', 'H')
# pair_choices2 with discarded term : ('B', 'D', 'H')
# A
# B
# D
# H
# makepair true
# ('A',)
# ('B', 'D', 'H')
# pair 1 ('A',)
# pair 2 ('B', 'D', 'activity')
# pair_choices2 with discarded term : ('B', 'D', 'activity')
# A
# B
# D
# activity
# pair 1 ('A',)
# pair 2 ('B', 'E', 'H')
# pair_choices2 with discarded term : ('B', 'E', 'H')
# A
# B
# E
# H
# makepair true
# ('A',)
# ('B', 'E', 'H')
# pair 1 ('A',)
# pair 2 ('B', 'E', 'activity')
# pair_choices2 with discarded term : ('B', 'E', 'activity')
# A
# B
# E
# activity
# pair 1 ('A',)
# pair 2 ('B', 'F', 'G')
# pair_choices2 with discarded term : ('B', 'F', 'G')
# A
# B
# F
# G
# pair 1 ('A',)
# pair 2 ('B', 'F', 'activity')
# pair_choices2 with discarded term : ('B', 'F', 'activity')
# A
# B
# F
# activity
# pair 1 ('A',)
# pair 2 ('B', 'G', 'activity')
# pair_choices2 with discarded term : ('B', 'G', 'activity')
# A
# B
# G
# pair 1 ('A',)
# pair 2 ('B', 'H', 'activity')
# pair_choices2 with discarded term : ('B', 'H', 'activity')
# A
# B
# H
# activity
# pair 1 ('A',)
# pair 2 ('C', 'E', 'H')
# pair_choices2 with discarded term : ('C', 'E', 'H')
# A
# C
# E
# H
# makepair true
# ('A',)
# ('C', 'E', 'H')
# pair 1 ('A',)
# pair 2 ('C', 'E', 'activity')
# pair_choices2 with discarded term : ('C', 'E', 'activity')
# A
# C
# E
# activity
# pair 1 ('A',)
# pair 2 ('C', 'F', 'G')
# pair_choices2 with discarded term : ('C', 'F', 'G')
# A
# C
# F
# G
# pair 1 ('A',)
# pair 2 ('C', 'F', 'activity')
# pair_choices2 with discarded term : ('C', 'F', 'activity')
# A
# C
# F
# activity
# pair 1 ('A',)
# pair 2 ('C', 'G', 'activity')
# pair_choices2 with discarded term : ('C', 'G', 'activity')
# A
# C
# G
# pair 1 ('A',)
# pair 2 ('C', 'H', 'activity')
# pair_choices2 with discarded term : ('C', 'H', 'activity')
# A
# C
# H
# activity
# pair 1 ('A',)
# pair 2 ('D', 'E', 'H')
# pair_choices2 with discarded term : ('D', 'E', 'H')
# A
# D
# E
# H
# makepair true
# ('A',)
# ('D', 'E', 'H')
# pair 1 ('A',)
# pair 2 ('D', 'E', 'activity')
# pair_choices2 with discarded term : ('D', 'E', 'activity')
# A
# D
# E
# activity
# pair 1 ('A',)
# pair 2 ('B', 'D', 'E', 'H')
# pair_choices2 with discarded term : ('B', 'D', 'E', 'H')
# A
# B
# D
# E
# H
# makepair true
# ('A',)
# ('B', 'D', 'E', 'H')
# pair 1 ('A',)
# pair 2 ('B', 'D', 'E', 'activity')
# pair_choices2 with discarded term : ('B', 'D', 'E', 'activity')
# A
# B
# D
# E
# activity
# pair 1 ('A',)
# pair 2 ('D', 'F', 'G')
# pair_choices2 with discarded term : ('D', 'F', 'G')
# A
# D
# F
# G
# pair 1 ('A',)
# pair 2 ('D', 'F', 'activity')
# pair_choices2 with discarded term : ('D', 'F', 'activity')
# A
# D
# F
# activity
# pair 1 ('A',)
# pair 2 ('B', 'D', 'F', 'G')
# pair_choices2 with discarded term : ('B', 'D', 'F', 'G')
# A
# B
# D
# F
# G
# pair 1 ('A',)
# pair 2 ('B', 'D', 'F', 'activity')
# pair_choices2 with discarded term : ('B', 'D', 'F', 'activity')
# A
# B
# D
# F
# activity
# pair 1 ('A',)
# pair 2 ('D', 'G', 'activity')
# pair_choices2 with discarded term : ('D', 'G', 'activity')
# A
# D
# G
# pair 1 ('A',)
# pair 2 ('B', 'D', 'G', 'activity')
# pair_choices2 with discarded term : ('B', 'D', 'G', 'activity')
# A
# B
# D
# G
# pair 1 ('A',)
# pair 2 ('D', 'F', 'G', 'activity')
# pair_choices2 with discarded term : ('D', 'F', 'G', 'activity')
# A
# D
# F
# G
# pair 1 ('A',)
# pair 2 ('B', 'D', 'F', 'G', 'activity')
# pair_choices2 with discarded term : ('B', 'D', 'F', 'G', 'activity')
# A
# B
# D
# F
# G
# pair 1 ('A',)
# pair 2 ('D', 'H', 'activity')
# pair_choices2 with discarded term : ('D', 'H', 'activity')
# A
# D
# H
# activity
# pair 1 ('A',)
# pair 2 ('B', 'D', 'H', 'activity')
# pair_choices2 with discarded term : ('B', 'D', 'H', 'activity')
# A
# B
# D
# H
# activity
# pair 1 ('A',)
# pair 2 ('D', 'E', 'H', 'activity')
# pair_choices2 with discarded term : ('D', 'E', 'H', 'activity')
# A
# D
# E
# H
# activity
# pair 1 ('A',)
# pair 2 ('B', 'D', 'E', 'H', 'activity')
# pair_choices2 with discarded term : ('B', 'D', 'E', 'H', 'activity')
# A
# B
# D
# E
# H
# activity
# pair 1 ('A',)
# pair 2 ('E', 'H', 'activity')
# pair_choices2 with discarded term : ('E', 'H', 'activity')
# A
# E
# H
# activity
# pair 1 ('A',)
# pair 2 ('B', 'E', 'H', 'activity')
# pair_choices2 with discarded term : ('B', 'E', 'H', 'activity')
# A
# B
# E
# H
# activity
# pair 1 ('A',)
# pair 2 ('C', 'E', 'H', 'activity')
# pair_choices2 with discarded term : ('C', 'E', 'H', 'activity')
# A
# C
# E
# H
# activity
# pair 1 ('A',)
# pair 2 ('F', 'G', 'activity')
# pair_choices2 with discarded term : ('F', 'G', 'activity')
# A
# F
# G
# pair 1 ('A',)
# pair 2 ('B', 'F', 'G', 'activity')
# pair_choices2 with discarded term : ('B', 'F', 'G', 'activity')
# A
# B
# F
# G
# pair 1 ('A',)
# pair 2 ('C', 'F', 'G', 'activity')
# pair_choices2 with discarded term : ('C', 'F', 'G', 'activity')
# A
# C
# F
# G
# pair 1 ('A', 'G')
# pair 2 ('A',)
# pair 1 ('A', 'G')
# pair 2 ('A', 'G')
# pair 1 ('A', 'G')
# pair 2 ('A', 'activity')
# pair_choices2 with discarded term : ('activity',)
# A
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('B', 'D')
# pair_choices2 with discarded term : ('B', 'D')
# A
# B
# D
# G
# B
# pair 1 ('A', 'G')
# pair 2 ('B', 'E')
# pair_choices2 with discarded term : ('B', 'E')
# A
# B
# E
# G
# B
# pair 1 ('A', 'G')
# pair 2 ('B', 'F')
# pair_choices2 with discarded term : ('B', 'F')
# A
# B
# F
# G
# B
# pair 1 ('A', 'G')
# pair 2 ('B', 'G')
# pair_choices2 with discarded term : ('B',)
# A
# B
# G
# B
# pair 1 ('A', 'G')
# pair 2 ('B', 'H')
# pair_choices2 with discarded term : ('B', 'H')
# A
# B
# H
# G
# B
# pair 1 ('A', 'G')
# pair 2 ('B', 'activity')
# pair_choices2 with discarded term : ('B', 'activity')
# A
# B
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('C', 'E')
# pair_choices2 with discarded term : ('C', 'E')
# A
# C
# E
# G
# C
# pair 1 ('A', 'G')
# pair 2 ('C', 'F')
# pair_choices2 with discarded term : ('C', 'F')
# A
# C
# F
# G
# C
# pair 1 ('A', 'G')
# pair 2 ('C', 'G')
# pair_choices2 with discarded term : ('C',)
# A
# C
# G
# C
# pair 1 ('A', 'G')
# pair 2 ('C', 'H')
# pair_choices2 with discarded term : ('C', 'H')
# A
# C
# H
# G
# C
# pair 1 ('A', 'G')
# pair 2 ('C', 'activity')
# pair_choices2 with discarded term : ('C', 'activity')
# A
# C
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('D', 'B')
# pair_choices2 with discarded term : ('B', 'D')
# A
# B
# D
# G
# B
# pair 1 ('A', 'G')
# pair 2 ('D',)
# pair_choices2 with discarded term : ('D',)
# A
# D
# G
# D
# pair 1 ('A', 'G')
# pair 2 ('D', 'E')
# pair_choices2 with discarded term : ('D', 'E')
# A
# D
# E
# G
# D
# pair 1 ('A', 'G')
# pair 2 ('D', 'F')
# pair_choices2 with discarded term : ('D', 'F')
# A
# D
# F
# G
# D
# pair 1 ('A', 'G')
# pair 2 ('D', 'G')
# pair_choices2 with discarded term : ('D',)
# A
# D
# G
# D
# pair 1 ('A', 'G')
# pair 2 ('D', 'H')
# pair_choices2 with discarded term : ('D', 'H')
# A
# D
# H
# G
# D
# pair 1 ('A', 'G')
# pair 2 ('D', 'activity')
# pair_choices2 with discarded term : ('D', 'activity')
# A
# D
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('E', 'B')
# pair_choices2 with discarded term : ('B', 'E')
# A
# B
# E
# G
# B
# pair 1 ('A', 'G')
# pair 2 ('E', 'C')
# pair_choices2 with discarded term : ('C', 'E')
# A
# C
# E
# G
# C
# pair 1 ('A', 'G')
# pair 2 ('E', 'D')
# pair_choices2 with discarded term : ('D', 'E')
# A
# D
# E
# G
# D
# pair 1 ('A', 'G')
# pair 2 ('E',)
# pair_choices2 with discarded term : ('E',)
# A
# E
# G
# E
# pair 1 ('A', 'G')
# pair 2 ('E', 'H')
# pair_choices2 with discarded term : ('E', 'H')
# A
# E
# H
# G
# E
# pair 1 ('A', 'G')
# pair 2 ('E', 'activity')
# pair_choices2 with discarded term : ('E', 'activity')
# A
# E
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('F', 'B')
# pair_choices2 with discarded term : ('B', 'F')
# A
# B
# F
# G
# B
# pair 1 ('A', 'G')
# pair 2 ('F', 'C')
# pair_choices2 with discarded term : ('C', 'F')
# A
# C
# F
# G
# C
# pair 1 ('A', 'G')
# pair 2 ('F', 'D')
# pair_choices2 with discarded term : ('D', 'F')
# A
# D
# F
# G
# D
# pair 1 ('A', 'G')
# pair 2 ('F',)
# pair_choices2 with discarded term : ('F',)
# A
# F
# G
# F
# pair 1 ('A', 'G')
# pair 2 ('F', 'G')
# pair_choices2 with discarded term : ('F',)
# A
# F
# G
# F
# pair 1 ('A', 'G')
# pair 2 ('F', 'activity')
# pair_choices2 with discarded term : ('F', 'activity')
# A
# F
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('G', 'A')
# pair 1 ('A', 'G')
# pair 2 ('G', 'B')
# pair_choices2 with discarded term : ('B',)
# A
# B
# G
# B
# pair 1 ('A', 'G')
# pair 2 ('G', 'C')
# pair_choices2 with discarded term : ('C',)
# A
# C
# G
# C
# pair 1 ('A', 'G')
# pair 2 ('G', 'D')
# pair_choices2 with discarded term : ('D',)
# A
# D
# G
# D
# pair 1 ('A', 'G')
# pair 2 ('G', 'F')
# pair_choices2 with discarded term : ('F',)
# A
# F
# G
# F
# pair 1 ('A', 'G')
# pair 2 ('G',)
# pair 1 ('A', 'G')
# pair 2 ('G', 'activity')
# pair_choices2 with discarded term : ('activity',)
# A
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('H', 'B')
# pair_choices2 with discarded term : ('B', 'H')
# A
# B
# H
# G
# B
# pair 1 ('A', 'G')
# pair 2 ('H', 'C')
# pair_choices2 with discarded term : ('C', 'H')
# A
# C
# H
# G
# C
# pair 1 ('A', 'G')
# pair 2 ('H', 'D')
# pair_choices2 with discarded term : ('D', 'H')
# A
# D
# H
# G
# D
# pair 1 ('A', 'G')
# pair 2 ('H', 'E')
# pair_choices2 with discarded term : ('E', 'H')
# A
# E
# H
# G
# E
# pair 1 ('A', 'G')
# pair 2 ('H',)
# pair_choices2 with discarded term : ('H',)
# A
# H
# G
# H
# makepair true
# ('A', 'G')
# ('H',)
# pair 1 ('A', 'G')
# pair 2 ('H', 'activity')
# pair_choices2 with discarded term : ('H', 'activity')
# A
# H
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('activity', 'A')
# pair_choices2 with discarded term : ('activity',)
# A
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('activity', 'B')
# pair_choices2 with discarded term : ('B', 'activity')
# A
# B
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('activity', 'C')
# pair_choices2 with discarded term : ('C', 'activity')
# A
# C
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('activity', 'D')
# pair_choices2 with discarded term : ('D', 'activity')
# A
# D
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('activity', 'E')
# pair_choices2 with discarded term : ('E', 'activity')
# A
# E
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('activity', 'F')
# pair_choices2 with discarded term : ('F', 'activity')
# A
# F
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('activity', 'G')
# pair_choices2 with discarded term : ('activity',)
# A
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('activity', 'H')
# pair_choices2 with discarded term : ('H', 'activity')
# A
# H
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('activity',)
# pair_choices2 with discarded term : ('activity',)
# A
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('A', 'G', 'activity')
# pair_choices2 with discarded term : ('activity',)
# A
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('B', 'D', 'E')
# pair_choices2 with discarded term : ('B', 'D', 'E')
# A
# B
# D
# E
# G
# B
# pair 1 ('A', 'G')
# pair 2 ('B', 'D', 'F')
# pair_choices2 with discarded term : ('B', 'D', 'F')
# A
# B
# D
# F
# G
# B
# pair 1 ('A', 'G')
# pair 2 ('B', 'D', 'G')
# pair_choices2 with discarded term : ('B', 'D')
# A
# B
# D
# G
# B
# pair 1 ('A', 'G')
# pair 2 ('B', 'D', 'H')
# pair_choices2 with discarded term : ('B', 'D', 'H')
# A
# B
# D
# H
# G
# B
# pair 1 ('A', 'G')
# pair 2 ('B', 'D', 'activity')
# pair_choices2 with discarded term : ('B', 'D', 'activity')
# A
# B
# D
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('B', 'E', 'H')
# pair_choices2 with discarded term : ('B', 'E', 'H')
# A
# B
# E
# H
# G
# B
# pair 1 ('A', 'G')
# pair 2 ('B', 'E', 'activity')
# pair_choices2 with discarded term : ('B', 'E', 'activity')
# A
# B
# E
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('B', 'F', 'G')
# pair_choices2 with discarded term : ('B', 'F')
# A
# B
# F
# G
# B
# pair 1 ('A', 'G')
# pair 2 ('B', 'F', 'activity')
# pair_choices2 with discarded term : ('B', 'F', 'activity')
# A
# B
# F
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('B', 'G', 'activity')
# pair_choices2 with discarded term : ('B', 'activity')
# A
# B
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('B', 'H', 'activity')
# pair_choices2 with discarded term : ('B', 'H', 'activity')
# A
# B
# H
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('C', 'E', 'H')
# pair_choices2 with discarded term : ('C', 'E', 'H')
# A
# C
# E
# H
# G
# C
# pair 1 ('A', 'G')
# pair 2 ('C', 'E', 'activity')
# pair_choices2 with discarded term : ('C', 'E', 'activity')
# A
# C
# E
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('C', 'F', 'G')
# pair_choices2 with discarded term : ('C', 'F')
# A
# C
# F
# G
# C
# pair 1 ('A', 'G')
# pair 2 ('C', 'F', 'activity')
# pair_choices2 with discarded term : ('C', 'F', 'activity')
# A
# C
# F
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('C', 'G', 'activity')
# pair_choices2 with discarded term : ('C', 'activity')
# A
# C
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('C', 'H', 'activity')
# pair_choices2 with discarded term : ('C', 'H', 'activity')
# A
# C
# H
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('D', 'E', 'H')
# pair_choices2 with discarded term : ('D', 'E', 'H')
# A
# D
# E
# H
# G
# D
# pair 1 ('A', 'G')
# pair 2 ('D', 'E', 'activity')
# pair_choices2 with discarded term : ('D', 'E', 'activity')
# A
# D
# E
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('B', 'D', 'E', 'H')
# pair_choices2 with discarded term : ('B', 'D', 'E', 'H')
# A
# B
# D
# E
# H
# G
# B
# pair 1 ('A', 'G')
# pair 2 ('B', 'D', 'E', 'activity')
# pair_choices2 with discarded term : ('B', 'D', 'E', 'activity')
# A
# B
# D
# E
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('D', 'F', 'G')
# pair_choices2 with discarded term : ('D', 'F')
# A
# D
# F
# G
# D
# pair 1 ('A', 'G')
# pair 2 ('D', 'F', 'activity')
# pair_choices2 with discarded term : ('D', 'F', 'activity')
# A
# D
# F
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('B', 'D', 'F', 'G')
# pair_choices2 with discarded term : ('B', 'D', 'F')
# A
# B
# D
# F
# G
# B
# pair 1 ('A', 'G')
# pair 2 ('B', 'D', 'F', 'activity')
# pair_choices2 with discarded term : ('B', 'D', 'F', 'activity')
# A
# B
# D
# F
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('D', 'G', 'activity')
# pair_choices2 with discarded term : ('D', 'activity')
# A
# D
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('B', 'D', 'G', 'activity')
# pair_choices2 with discarded term : ('B', 'D', 'activity')
# A
# B
# D
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('D', 'F', 'G', 'activity')
# pair_choices2 with discarded term : ('D', 'F', 'activity')
# A
# D
# F
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('B', 'D', 'F', 'G', 'activity')
# pair_choices2 with discarded term : ('B', 'D', 'F', 'activity')
# A
# B
# D
# F
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('D', 'H', 'activity')
# pair_choices2 with discarded term : ('D', 'H', 'activity')
# A
# D
# H
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('B', 'D', 'H', 'activity')
# pair_choices2 with discarded term : ('B', 'D', 'H', 'activity')
# A
# B
# D
# H
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('D', 'E', 'H', 'activity')
# pair_choices2 with discarded term : ('D', 'E', 'H', 'activity')
# A
# D
# E
# H
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('B', 'D', 'E', 'H', 'activity')
# pair_choices2 with discarded term : ('B', 'D', 'E', 'H', 'activity')
# A
# B
# D
# E
# H
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('E', 'H', 'activity')
# pair_choices2 with discarded term : ('E', 'H', 'activity')
# A
# E
# H
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('B', 'E', 'H', 'activity')
# pair_choices2 with discarded term : ('B', 'E', 'H', 'activity')
# A
# B
# E
# H
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('C', 'E', 'H', 'activity')
# pair_choices2 with discarded term : ('C', 'E', 'H', 'activity')
# A
# C
# E
# H
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('F', 'G', 'activity')
# pair_choices2 with discarded term : ('F', 'activity')
# A
# F
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('B', 'F', 'G', 'activity')
# pair_choices2 with discarded term : ('B', 'F', 'activity')
# A
# B
# F
# activity
# G
# pair 1 ('A', 'G')
# pair 2 ('C', 'F', 'G', 'activity')
# pair_choices2 with discarded term : ('C', 'F', 'activity')
# A
# C
# F
# activity
# G
# pair 1 ('A', 'activity')
# pair 2 ('A',)
# pair 1 ('A', 'activity')
# pair 2 ('A', 'G')
# pair_choices2 with discarded term : ('G',)
# A
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('A', 'activity')
# pair 1 ('A', 'activity')
# pair 2 ('B', 'D')
# pair_choices2 with discarded term : ('B', 'D')
# A
# B
# D
# activity
# B
# pair 1 ('A', 'activity')
# pair 2 ('B', 'E')
# pair_choices2 with discarded term : ('B', 'E')
# A
# B
# E
# activity
# B
# pair 1 ('A', 'activity')
# pair 2 ('B', 'F')
# pair_choices2 with discarded term : ('B', 'F')
# A
# B
# F
# activity
# B
# pair 1 ('A', 'activity')
# pair 2 ('B', 'G')
# pair_choices2 with discarded term : ('B', 'G')
# A
# B
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('B', 'H')
# pair_choices2 with discarded term : ('B', 'H')
# A
# B
# H
# activity
# B
# pair 1 ('A', 'activity')
# pair 2 ('B', 'activity')
# pair_choices2 with discarded term : ('B',)
# A
# B
# activity
# B
# pair 1 ('A', 'activity')
# pair 2 ('C', 'E')
# pair_choices2 with discarded term : ('C', 'E')
# A
# C
# E
# activity
# C
# pair 1 ('A', 'activity')
# pair 2 ('C', 'F')
# pair_choices2 with discarded term : ('C', 'F')
# A
# C
# F
# activity
# C
# pair 1 ('A', 'activity')
# pair 2 ('C', 'G')
# pair_choices2 with discarded term : ('C', 'G')
# A
# C
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('C', 'H')
# pair_choices2 with discarded term : ('C', 'H')
# A
# C
# H
# activity
# C
# pair 1 ('A', 'activity')
# pair 2 ('C', 'activity')
# pair_choices2 with discarded term : ('C',)
# A
# C
# activity
# C
# pair 1 ('A', 'activity')
# pair 2 ('D', 'B')
# pair_choices2 with discarded term : ('B', 'D')
# A
# B
# D
# activity
# B
# pair 1 ('A', 'activity')
# pair 2 ('D',)
# pair_choices2 with discarded term : ('D',)
# A
# D
# activity
# D
# pair 1 ('A', 'activity')
# pair 2 ('D', 'E')
# pair_choices2 with discarded term : ('D', 'E')
# A
# D
# E
# activity
# D
# pair 1 ('A', 'activity')
# pair 2 ('D', 'F')
# pair_choices2 with discarded term : ('D', 'F')
# A
# D
# F
# activity
# D
# pair 1 ('A', 'activity')
# pair 2 ('D', 'G')
# pair_choices2 with discarded term : ('D', 'G')
# A
# D
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('D', 'H')
# pair_choices2 with discarded term : ('D', 'H')
# A
# D
# H
# activity
# D
# pair 1 ('A', 'activity')
# pair 2 ('D', 'activity')
# pair_choices2 with discarded term : ('D',)
# A
# D
# activity
# D
# pair 1 ('A', 'activity')
# pair 2 ('E', 'B')
# pair_choices2 with discarded term : ('B', 'E')
# A
# B
# E
# activity
# B
# pair 1 ('A', 'activity')
# pair 2 ('E', 'C')
# pair_choices2 with discarded term : ('C', 'E')
# A
# C
# E
# activity
# C
# pair 1 ('A', 'activity')
# pair 2 ('E', 'D')
# pair_choices2 with discarded term : ('D', 'E')
# A
# D
# E
# activity
# D
# pair 1 ('A', 'activity')
# pair 2 ('E',)
# pair_choices2 with discarded term : ('E',)
# A
# E
# activity
# E
# pair 1 ('A', 'activity')
# pair 2 ('E', 'H')
# pair_choices2 with discarded term : ('E', 'H')
# A
# E
# H
# activity
# E
# pair 1 ('A', 'activity')
# pair 2 ('E', 'activity')
# pair_choices2 with discarded term : ('E',)
# A
# E
# activity
# E
# pair 1 ('A', 'activity')
# pair 2 ('F', 'B')
# pair_choices2 with discarded term : ('B', 'F')
# A
# B
# F
# activity
# B
# pair 1 ('A', 'activity')
# pair 2 ('F', 'C')
# pair_choices2 with discarded term : ('C', 'F')
# A
# C
# F
# activity
# C
# pair 1 ('A', 'activity')
# pair 2 ('F', 'D')
# pair_choices2 with discarded term : ('D', 'F')
# A
# D
# F
# activity
# D
# pair 1 ('A', 'activity')
# pair 2 ('F',)
# pair_choices2 with discarded term : ('F',)
# A
# F
# activity
# F
# pair 1 ('A', 'activity')
# pair 2 ('F', 'G')
# pair_choices2 with discarded term : ('F', 'G')
# A
# F
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('F', 'activity')
# pair_choices2 with discarded term : ('F',)
# A
# F
# activity
# F
# pair 1 ('A', 'activity')
# pair 2 ('G', 'A')
# pair_choices2 with discarded term : ('G',)
# A
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('G', 'B')
# pair_choices2 with discarded term : ('B', 'G')
# A
# B
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('G', 'C')
# pair_choices2 with discarded term : ('C', 'G')
# A
# C
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('G', 'D')
# pair_choices2 with discarded term : ('D', 'G')
# A
# D
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('G', 'F')
# pair_choices2 with discarded term : ('F', 'G')
# A
# F
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('G',)
# pair_choices2 with discarded term : ('G',)
# A
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('G', 'activity')
# pair_choices2 with discarded term : ('G',)
# A
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('H', 'B')
# pair_choices2 with discarded term : ('B', 'H')
# A
# B
# H
# activity
# B
# pair 1 ('A', 'activity')
# pair 2 ('H', 'C')
# pair_choices2 with discarded term : ('C', 'H')
# A
# C
# H
# activity
# C
# pair 1 ('A', 'activity')
# pair 2 ('H', 'D')
# pair_choices2 with discarded term : ('D', 'H')
# A
# D
# H
# activity
# D
# pair 1 ('A', 'activity')
# pair 2 ('H', 'E')
# pair_choices2 with discarded term : ('E', 'H')
# A
# E
# H
# activity
# E
# pair 1 ('A', 'activity')
# pair 2 ('H',)
# pair_choices2 with discarded term : ('H',)
# A
# H
# activity
# H
# pair 1 ('A', 'activity')
# pair 2 ('H', 'activity')
# pair_choices2 with discarded term : ('H',)
# A
# H
# activity
# H
# pair 1 ('A', 'activity')
# pair 2 ('activity', 'A')
# pair 1 ('A', 'activity')
# pair 2 ('activity', 'B')
# pair_choices2 with discarded term : ('B',)
# A
# B
# activity
# B
# pair 1 ('A', 'activity')
# pair 2 ('activity', 'C')
# pair_choices2 with discarded term : ('C',)
# A
# C
# activity
# C
# pair 1 ('A', 'activity')
# pair 2 ('activity', 'D')
# pair_choices2 with discarded term : ('D',)
# A
# D
# activity
# D
# pair 1 ('A', 'activity')
# pair 2 ('activity', 'E')
# pair_choices2 with discarded term : ('E',)
# A
# E
# activity
# E
# pair 1 ('A', 'activity')
# pair 2 ('activity', 'F')
# pair_choices2 with discarded term : ('F',)
# A
# F
# activity
# F
# pair 1 ('A', 'activity')
# pair 2 ('activity', 'G')
# pair_choices2 with discarded term : ('G',)
# A
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('activity', 'H')
# pair_choices2 with discarded term : ('H',)
# A
# H
# activity
# H
# pair 1 ('A', 'activity')
# pair 2 ('activity',)
# pair 1 ('A', 'activity')
# pair 2 ('A', 'G', 'activity')
# pair_choices2 with discarded term : ('G',)
# A
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('B', 'D', 'E')
# pair_choices2 with discarded term : ('B', 'D', 'E')
# A
# B
# D
# E
# activity
# B
# pair 1 ('A', 'activity')
# pair 2 ('B', 'D', 'F')
# pair_choices2 with discarded term : ('B', 'D', 'F')
# A
# B
# D
# F
# activity
# B
# pair 1 ('A', 'activity')
# pair 2 ('B', 'D', 'G')
# pair_choices2 with discarded term : ('B', 'D', 'G')
# A
# B
# D
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('B', 'D', 'H')
# pair_choices2 with discarded term : ('B', 'D', 'H')
# A
# B
# D
# H
# activity
# B
# pair 1 ('A', 'activity')
# pair 2 ('B', 'D', 'activity')
# pair_choices2 with discarded term : ('B', 'D')
# A
# B
# D
# activity
# B
# pair 1 ('A', 'activity')
# pair 2 ('B', 'E', 'H')
# pair_choices2 with discarded term : ('B', 'E', 'H')
# A
# B
# E
# H
# activity
# B
# pair 1 ('A', 'activity')
# pair 2 ('B', 'E', 'activity')
# pair_choices2 with discarded term : ('B', 'E')
# A
# B
# E
# activity
# B
# pair 1 ('A', 'activity')
# pair 2 ('B', 'F', 'G')
# pair_choices2 with discarded term : ('B', 'F', 'G')
# A
# B
# F
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('B', 'F', 'activity')
# pair_choices2 with discarded term : ('B', 'F')
# A
# B
# F
# activity
# B
# pair 1 ('A', 'activity')
# pair 2 ('B', 'G', 'activity')
# pair_choices2 with discarded term : ('B', 'G')
# A
# B
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('B', 'H', 'activity')
# pair_choices2 with discarded term : ('B', 'H')
# A
# B
# H
# activity
# B
# pair 1 ('A', 'activity')
# pair 2 ('C', 'E', 'H')
# pair_choices2 with discarded term : ('C', 'E', 'H')
# A
# C
# E
# H
# activity
# C
# pair 1 ('A', 'activity')
# pair 2 ('C', 'E', 'activity')
# pair_choices2 with discarded term : ('C', 'E')
# A
# C
# E
# activity
# C
# pair 1 ('A', 'activity')
# pair 2 ('C', 'F', 'G')
# pair_choices2 with discarded term : ('C', 'F', 'G')
# A
# C
# F
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('C', 'F', 'activity')
# pair_choices2 with discarded term : ('C', 'F')
# A
# C
# F
# activity
# C
# pair 1 ('A', 'activity')
# pair 2 ('C', 'G', 'activity')
# pair_choices2 with discarded term : ('C', 'G')
# A
# C
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('C', 'H', 'activity')
# pair_choices2 with discarded term : ('C', 'H')
# A
# C
# H
# activity
# C
# pair 1 ('A', 'activity')
# pair 2 ('D', 'E', 'H')
# pair_choices2 with discarded term : ('D', 'E', 'H')
# A
# D
# E
# H
# activity
# D
# pair 1 ('A', 'activity')
# pair 2 ('D', 'E', 'activity')
# pair_choices2 with discarded term : ('D', 'E')
# A
# D
# E
# activity
# D
# pair 1 ('A', 'activity')
# pair 2 ('B', 'D', 'E', 'H')
# pair_choices2 with discarded term : ('B', 'D', 'E', 'H')
# A
# B
# D
# E
# H
# activity
# B
# pair 1 ('A', 'activity')
# pair 2 ('B', 'D', 'E', 'activity')
# pair_choices2 with discarded term : ('B', 'D', 'E')
# A
# B
# D
# E
# activity
# B
# pair 1 ('A', 'activity')
# pair 2 ('D', 'F', 'G')
# pair_choices2 with discarded term : ('D', 'F', 'G')
# A
# D
# F
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('D', 'F', 'activity')
# pair_choices2 with discarded term : ('D', 'F')
# A
# D
# F
# activity
# D
# pair 1 ('A', 'activity')
# pair 2 ('B', 'D', 'F', 'G')
# pair_choices2 with discarded term : ('B', 'D', 'F', 'G')
# A
# B
# D
# F
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('B', 'D', 'F', 'activity')
# pair_choices2 with discarded term : ('B', 'D', 'F')
# A
# B
# D
# F
# activity
# B
# pair 1 ('A', 'activity')
# pair 2 ('D', 'G', 'activity')
# pair_choices2 with discarded term : ('D', 'G')
# A
# D
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('B', 'D', 'G', 'activity')
# pair_choices2 with discarded term : ('B', 'D', 'G')
# A
# B
# D
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('D', 'F', 'G', 'activity')
# pair_choices2 with discarded term : ('D', 'F', 'G')
# A
# D
# F
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('B', 'D', 'F', 'G', 'activity')
# pair_choices2 with discarded term : ('B', 'D', 'F', 'G')
# A
# B
# D
# F
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('D', 'H', 'activity')
# pair_choices2 with discarded term : ('D', 'H')
# A
# D
# H
# activity
# D
# pair 1 ('A', 'activity')
# pair 2 ('B', 'D', 'H', 'activity')
# pair_choices2 with discarded term : ('B', 'D', 'H')
# A
# B
# D
# H
# activity
# B
# pair 1 ('A', 'activity')
# pair 2 ('D', 'E', 'H', 'activity')
# pair_choices2 with discarded term : ('D', 'E', 'H')
# A
# D
# E
# H
# activity
# D
# pair 1 ('A', 'activity')
# pair 2 ('B', 'D', 'E', 'H', 'activity')
# pair_choices2 with discarded term : ('B', 'D', 'E', 'H')
# A
# B
# D
# E
# H
# activity
# B
# pair 1 ('A', 'activity')
# pair 2 ('E', 'H', 'activity')
# pair_choices2 with discarded term : ('E', 'H')
# A
# E
# H
# activity
# E
# pair 1 ('A', 'activity')
# pair 2 ('B', 'E', 'H', 'activity')
# pair_choices2 with discarded term : ('B', 'E', 'H')
# A
# B
# E
# H
# activity
# B
# pair 1 ('A', 'activity')
# pair 2 ('C', 'E', 'H', 'activity')
# pair_choices2 with discarded term : ('C', 'E', 'H')
# A
# C
# E
# H
# activity
# C
# pair 1 ('A', 'activity')
# pair 2 ('F', 'G', 'activity')
# pair_choices2 with discarded term : ('F', 'G')
# A
# F
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('B', 'F', 'G', 'activity')
# pair_choices2 with discarded term : ('B', 'F', 'G')
# A
# B
# F
# G
# activity
# pair 1 ('A', 'activity')
# pair 2 ('C', 'F', 'G', 'activity')
# pair_choices2 with discarded term : ('C', 'F', 'G')
# A
# C
# F
# G
# activity
# pair 1 ('B', 'D')
# pair 2 ('A',)
# pair_choices2 with discarded term : ('A',)
# B
# A
# D
# pair 1 ('B', 'D')
# pair 2 ('A', 'G')
# pair_choices2 with discarded term : ('A', 'G')
# B
# A
# D
# pair 1 ('B', 'D')
# pair 2 ('A', 'activity')
# pair_choices2 with discarded term : ('A', 'activity')
# B
# A
# D
# pair 1 ('B', 'D')
# pair 2 ('B', 'D')
# pair 1 ('B', 'D')
# pair 2 ('B', 'E')
# pair_choices2 with discarded term : ('E',)
# B
# E
# D
# pair 1 ('B', 'D')
# pair 2 ('B', 'F')
# pair_choices2 with discarded term : ('F',)
# B
# F
# D
# pair 1 ('B', 'D')
# pair 2 ('B', 'G')
# pair_choices2 with discarded term : ('G',)
# B
# G
# D
# pair 1 ('B', 'D')
# pair 2 ('B', 'H')
# pair_choices2 with discarded term : ('H',)
# B
# H
# D
# pair 1 ('B', 'D')
# pair 2 ('B', 'activity')
# pair_choices2 with discarded term : ('activity',)
# B
# activity
# D
# pair 1 ('B', 'D')
# pair 2 ('C', 'E')
# pair_choices2 with discarded term : ('C', 'E')
# B
# C
# D
# pair 1 ('B', 'D')
# pair 2 ('C', 'F')
# pair_choices2 with discarded term : ('C', 'F')
# B
# C
# D
# pair 1 ('B', 'D')
# pair 2 ('C', 'G')
# pair_choices2 with discarded term : ('C', 'G')
# B
# C
# D
# pair 1 ('B', 'D')
# pair 2 ('C', 'H')
# pair_choices2 with discarded term : ('C', 'H')
# B
# C
# D
# pair 1 ('B', 'D')
# pair 2 ('C', 'activity')
# pair_choices2 with discarded term : ('C', 'activity')
# B
# C
# D
# pair 1 ('B', 'D')
# pair 2 ('D', 'B')
# pair 1 ('B', 'D')
# pair 2 ('D',)
# pair 1 ('B', 'D')
# pair 2 ('D', 'E')
# pair_choices2 with discarded term : ('E',)
# B
# E
# D
# pair 1 ('B', 'D')
# pair 2 ('D', 'F')
# pair_choices2 with discarded term : ('F',)
# B
# F
# D
# pair 1 ('B', 'D')
# pair 2 ('D', 'G')
# pair_choices2 with discarded term : ('G',)
# B
# G
# D
# pair 1 ('B', 'D')
# pair 2 ('D', 'H')
# pair_choices2 with discarded term : ('H',)
# B
# H
# D
# pair 1 ('B', 'D')
# pair 2 ('D', 'activity')
# pair_choices2 with discarded term : ('activity',)
# B
# activity
# D
# pair 1 ('B', 'D')
# pair 2 ('E', 'B')
# pair_choices2 with discarded term : ('E',)
# B
# E
# D
# pair 1 ('B', 'D')
# pair 2 ('E', 'C')
# pair_choices2 with discarded term : ('C', 'E')
# B
# C
# D
# pair 1 ('B', 'D')
# pair 2 ('E', 'D')
# pair_choices2 with discarded term : ('E',)
# B
# E
# D
# pair 1 ('B', 'D')
# pair 2 ('E',)
# pair_choices2 with discarded term : ('E',)
# B
# E
# D
# pair 1 ('B', 'D')
# pair 2 ('E', 'H')
# pair_choices2 with discarded term : ('E', 'H')
# B
# E
# D
# pair 1 ('B', 'D')
# pair 2 ('E', 'activity')
# pair_choices2 with discarded term : ('E', 'activity')
# B
# E
# D
# pair 1 ('B', 'D')
# pair 2 ('F', 'B')
# pair_choices2 with discarded term : ('F',)
# B
# F
# D
# pair 1 ('B', 'D')
# pair 2 ('F', 'C')
# pair_choices2 with discarded term : ('C', 'F')
# B
# C
# D
# pair 1 ('B', 'D')
# pair 2 ('F', 'D')
# pair_choices2 with discarded term : ('F',)
# B
# F
# D
# pair 1 ('B', 'D')
# pair 2 ('F',)
# pair_choices2 with discarded term : ('F',)
# B
# F
# D
# pair 1 ('B', 'D')
# pair 2 ('F', 'G')
# pair_choices2 with discarded term : ('F', 'G')
# B
# F
# D
# pair 1 ('B', 'D')
# pair 2 ('F', 'activity')
# pair_choices2 with discarded term : ('F', 'activity')
# B
# F
# D
# pair 1 ('B', 'D')
# pair 2 ('G', 'A')
# pair_choices2 with discarded term : ('A', 'G')
# B
# A
# D
# pair 1 ('B', 'D')
# pair 2 ('G', 'B')
# pair_choices2 with discarded term : ('G',)
# B
# G
# D
# pair 1 ('B', 'D')
# pair 2 ('G', 'C')
# pair_choices2 with discarded term : ('C', 'G')
# B
# C
# D
# pair 1 ('B', 'D')
# pair 2 ('G', 'D')
# pair_choices2 with discarded term : ('G',)
# B
# G
# D
# pair 1 ('B', 'D')
# pair 2 ('G', 'F')
# pair_choices2 with discarded term : ('F', 'G')
# B
# F
# D
# pair 1 ('B', 'D')
# pair 2 ('G',)
# pair_choices2 with discarded term : ('G',)
# B
# G
# D
# pair 1 ('B', 'D')
# pair 2 ('G', 'activity')
# pair_choices2 with discarded term : ('G', 'activity')
# B
# G
# D
# pair 1 ('B', 'D')
# pair 2 ('H', 'B')
# pair_choices2 with discarded term : ('H',)
# B
# H
# D
# pair 1 ('B', 'D')
# pair 2 ('H', 'C')
# pair_choices2 with discarded term : ('C', 'H')
# B
# C
# D
# pair 1 ('B', 'D')
# pair 2 ('H', 'D')
# pair_choices2 with discarded term : ('H',)
# B
# H
# D
# pair 1 ('B', 'D')
# pair 2 ('H', 'E')
# pair_choices2 with discarded term : ('E', 'H')
# B
# E
# D
# pair 1 ('B', 'D')
# pair 2 ('H',)
# pair_choices2 with discarded term : ('H',)
# B
# H
# D
# pair 1 ('B', 'D')
# pair 2 ('H', 'activity')
# pair_choices2 with discarded term : ('H', 'activity')
# B
# H
# D
# pair 1 ('B', 'D')
# pair 2 ('activity', 'A')
# pair_choices2 with discarded term : ('A', 'activity')
# B
# A
# D
# pair 1 ('B', 'D')
# pair 2 ('activity', 'B')
# pair_choices2 with discarded term : ('activity',)
# B
# activity
# D
# pair 1 ('B', 'D')
# pair 2 ('activity', 'C')
# pair_choices2 with discarded term : ('C', 'activity')
# B
# C
# D
# pair 1 ('B', 'D')
# pair 2 ('activity', 'D')
# pair_choices2 with discarded term : ('activity',)
# B
# activity
# D
# pair 1 ('B', 'D')
# pair 2 ('activity', 'E')
# pair_choices2 with discarded term : ('E', 'activity')
# B
# E
# D
# pair 1 ('B', 'D')
# pair 2 ('activity', 'F')
# pair_choices2 with discarded term : ('F', 'activity')
# B
# F
# D
# pair 1 ('B', 'D')
# pair 2 ('activity', 'G')
# pair_choices2 with discarded term : ('G', 'activity')
# B
# G
# D
# pair 1 ('B', 'D')
# pair 2 ('activity', 'H')
# pair_choices2 with discarded term : ('H', 'activity')
# B
# H
# D
# pair 1 ('B', 'D')
# pair 2 ('activity',)
# pair_choices2 with discarded term : ('activity',)
# B
# activity
# D
# pair 1 ('B', 'D')
# pair 2 ('A', 'G', 'activity')
# pair_choices2 with discarded term : ('A', 'G', 'activity')
# B
# A
# D
# pair 1 ('B', 'D')
# pair 2 ('B', 'D', 'E')
# pair_choices2 with discarded term : ('E',)
# B
# E
# D
# pair 1 ('B', 'D')
# pair 2 ('B', 'D', 'F')
# pair_choices2 with discarded term : ('F',)
# B
# F
# D
# pair 1 ('B', 'D')
# pair 2 ('B', 'D', 'G')
# pair_choices2 with discarded term : ('G',)
# B
# G
# D
# pair 1 ('B', 'D')
# pair 2 ('B', 'D', 'H')
# pair_choices2 with discarded term : ('H',)
# B
# H
# D
# pair 1 ('B', 'D')
# pair 2 ('B', 'D', 'activity')
# pair_choices2 with discarded term : ('activity',)
# B
# activity
# D
# pair 1 ('B', 'D')
# pair 2 ('B', 'E', 'H')
# pair_choices2 with discarded term : ('E', 'H')
# B
# E
# D
# pair 1 ('B', 'D')
# pair 2 ('B', 'E', 'activity')
# pair_choices2 with discarded term : ('E', 'activity')
# B
# E
# D
# pair 1 ('B', 'D')
# pair 2 ('B', 'F', 'G')
# pair_choices2 with discarded term : ('F', 'G')
# B
# F
# D
# pair 1 ('B', 'D')
# pair 2 ('B', 'F', 'activity')
# pair_choices2 with discarded term : ('F', 'activity')
# B
# F
# D
# pair 1 ('B', 'D')
# pair 2 ('B', 'G', 'activity')
# pair_choices2 with discarded term : ('G', 'activity')
# B
# G
# D
# pair 1 ('B', 'D')
# pair 2 ('B', 'H', 'activity')
# pair_choices2 with discarded term : ('H', 'activity')
# B
# H
# D
# pair 1 ('B', 'D')
# pair 2 ('C', 'E', 'H')
# pair_choices2 with discarded term : ('C', 'E', 'H')
# B
# C
# D
# pair 1 ('B', 'D')
# pair 2 ('C', 'E', 'activity')
# pair_choices2 with discarded term : ('C', 'E', 'activity')
# B
# C
# D
# pair 1 ('B', 'D')
# pair 2 ('C', 'F', 'G')
# pair_choices2 with discarded term : ('C', 'F', 'G')
# B
# C
# D
# pair 1 ('B', 'D')
# pair 2 ('C', 'F', 'activity')
# pair_choices2 with discarded term : ('C', 'F', 'activity')
# B
# C
# D
# pair 1 ('B', 'D')
# pair 2 ('C', 'G', 'activity')
# pair_choices2 with discarded term : ('C', 'G', 'activity')
# B
# C
# D
# pair 1 ('B', 'D')
# pair 2 ('C', 'H', 'activity')
# pair_choices2 with discarded term : ('C', 'H', 'activity')
# B
# C
# D
# pair 1 ('B', 'D')
# pair 2 ('D', 'E', 'H')
# pair_choices2 with discarded term : ('E', 'H')
# B
# E
# D
# pair 1 ('B', 'D')
# pair 2 ('D', 'E', 'activity')
# pair_choices2 with discarded term : ('E', 'activity')
# B
# E
# D
# pair 1 ('B', 'D')
# pair 2 ('B', 'D', 'E', 'H')
# pair_choices2 with discarded term : ('E', 'H')
# B
# E
# D
# pair 1 ('B', 'D')
# pair 2 ('B', 'D', 'E', 'activity')
# pair_choices2 with discarded term : ('E', 'activity')
# B
# E
# D
# pair 1 ('B', 'D')
# pair 2 ('D', 'F', 'G')
# pair_choices2 with discarded term : ('F', 'G')
# B
# F
# D
# pair 1 ('B', 'D')
# pair 2 ('D', 'F', 'activity')
# pair_choices2 with discarded term : ('F', 'activity')
# B
# F
# D
# pair 1 ('B', 'D')
# pair 2 ('B', 'D', 'F', 'G')
# pair_choices2 with discarded term : ('F', 'G')
# B
# F
# D
# pair 1 ('B', 'D')
# pair 2 ('B', 'D', 'F', 'activity')
# pair_choices2 with discarded term : ('F', 'activity')
# B
# F
# D
# pair 1 ('B', 'D')
# pair 2 ('D', 'G', 'activity')
# pair_choices2 with discarded term : ('G', 'activity')
# B
# G
# D
# pair 1 ('B', 'D')
# pair 2 ('B', 'D', 'G', 'activity')
# pair_choices2 with discarded term : ('G', 'activity')
# B
# G
# D
# pair 1 ('B', 'D')
# pair 2 ('D', 'F', 'G', 'activity')
# pair_choices2 with discarded term : ('F', 'G', 'activity')
# B
# F
# D
# pair 1 ('B', 'D')
# pair 2 ('B', 'D', 'F', 'G', 'activity')
# pair_choices2 with discarded term : ('F', 'G', 'activity')
# B
# F
# D
# pair 1 ('B', 'D')
# pair 2 ('D', 'H', 'activity')
# pair_choices2 with discarded term : ('H', 'activity')
# B
# H
# D
# pair 1 ('B', 'D')
# pair 2 ('B', 'D', 'H', 'activity')
# pair_choices2 with discarded term : ('H', 'activity')
# B
# H
# D
# pair 1 ('B', 'D')
# pair 2 ('D', 'E', 'H', 'activity')
# pair_choices2 with discarded term : ('E', 'H', 'activity')
# B
# E
# D
# pair 1 ('B', 'D')
# pair 2 ('B', 'D', 'E', 'H', 'activity')
# pair_choices2 with discarded term : ('E', 'H', 'activity')
# B
# E
# D
# pair 1 ('B', 'D')
# pair 2 ('E', 'H', 'activity')
# pair_choices2 with discarded term : ('E', 'H', 'activity')
# B
# E
# D
# pair 1 ('B', 'D')
# pair 2 ('B', 'E', 'H', 'activity')
# pair_choices2 with discarded term : ('E', 'H', 'activity')
# B
# E
# D
# pair 1 ('B', 'D')
# pair 2 ('C', 'E', 'H', 'activity')
# pair_choices2 with discarded term : ('C', 'E', 'H', 'activity')
# B
# C
# D
# pair 1 ('B', 'D')
# pair 2 ('F', 'G', 'activity')
# pair_choices2 with discarded term : ('F', 'G', 'activity')
# B
# F
# D
# pair 1 ('B', 'D')
# pair 2 ('B', 'F', 'G', 'activity')
# pair_choices2 with discarded term : ('F', 'G', 'activity')
# B
# F
# D
# pair 1 ('B', 'D')
# pair 2 ('C', 'F', 'G', 'activity')
# pair_choices2 with discarded term : ('C', 'F', 'G', 'activity')
# B
# C
# D
# pair 1 ('B', 'E')
# pair 2 ('A',)
# pair_choices2 with discarded term : ('A',)
# B
# A
# E
# pair 1 ('B', 'E')
# pair 2 ('A', 'G')
# pair_choices2 with discarded term : ('A', 'G')
# B
# A
# E
# pair 1 ('B', 'E')
# pair 2 ('A', 'activity')
# pair_choices2 with discarded term : ('A', 'activity')
# B
# A
# E
# pair 1 ('B', 'E')
# pair 2 ('B', 'D')
# pair_choices2 with discarded term : ('D',)
# B
# D
# E
# pair 1 ('B', 'E')
# pair 2 ('B', 'E')
# pair 1 ('B', 'E')
# pair 2 ('B', 'F')
# pair_choices2 with discarded term : ('F',)
# B
# F
# E
# pair 1 ('B', 'E')
# pair 2 ('B', 'G')
# pair_choices2 with discarded term : ('G',)
# B
# G
# E
# pair 1 ('B', 'E')
# pair 2 ('B', 'H')
# pair_choices2 with discarded term : ('H',)
# B
# H
# E
# pair 1 ('B', 'E')
# pair 2 ('B', 'activity')
# pair_choices2 with discarded term : ('activity',)
# B
# activity
# E
# pair 1 ('B', 'E')
# pair 2 ('C', 'E')
# pair_choices2 with discarded term : ('C',)
# B
# C
# E
# pair 1 ('B', 'E')
# pair 2 ('C', 'F')
# pair_choices2 with discarded term : ('C', 'F')
# B
# C
# E
# pair 1 ('B', 'E')
# pair 2 ('C', 'G')
# pair_choices2 with discarded term : ('C', 'G')
# B
# C
# E
# pair 1 ('B', 'E')
# pair 2 ('C', 'H')
# pair_choices2 with discarded term : ('C', 'H')
# B
# C
# E
# pair 1 ('B', 'E')
# pair 2 ('C', 'activity')
# pair_choices2 with discarded term : ('C', 'activity')
# B
# C
# E
# pair 1 ('B', 'E')
# pair 2 ('D', 'B')
# pair_choices2 with discarded term : ('D',)
# B
# D
# E
# pair 1 ('B', 'E')
# pair 2 ('D',)
# pair_choices2 with discarded term : ('D',)
# B
# D
# E
# pair 1 ('B', 'E')
# pair 2 ('D', 'E')
# pair_choices2 with discarded term : ('D',)
# B
# D
# E
# pair 1 ('B', 'E')
# pair 2 ('D', 'F')
# pair_choices2 with discarded term : ('D', 'F')
# B
# D
# E
# pair 1 ('B', 'E')
# pair 2 ('D', 'G')
# pair_choices2 with discarded term : ('D', 'G')
# B
# D
# E
# pair 1 ('B', 'E')
# pair 2 ('D', 'H')
# pair_choices2 with discarded term : ('D', 'H')
# B
# D
# E
# pair 1 ('B', 'E')
# pair 2 ('D', 'activity')
# pair_choices2 with discarded term : ('D', 'activity')
# B
# D
# E
# pair 1 ('B', 'E')
# pair 2 ('E', 'B')
# pair 1 ('B', 'E')
# pair 2 ('E', 'C')
# pair_choices2 with discarded term : ('C',)
# B
# C
# E
# pair 1 ('B', 'E')
# pair 2 ('E', 'D')
# pair_choices2 with discarded term : ('D',)
# B
# D
# E
# pair 1 ('B', 'E')
# pair 2 ('E',)
# pair 1 ('B', 'E')
# pair 2 ('E', 'H')
# pair_choices2 with discarded term : ('H',)
# B
# H
# E
# pair 1 ('B', 'E')
# pair 2 ('E', 'activity')
# pair_choices2 with discarded term : ('activity',)
# B
# activity
# E
# pair 1 ('B', 'E')
# pair 2 ('F', 'B')
# pair_choices2 with discarded term : ('F',)
# B
# F
# E
# pair 1 ('B', 'E')
# pair 2 ('F', 'C')
# pair_choices2 with discarded term : ('C', 'F')
# B
# C
# E
# pair 1 ('B', 'E')
# pair 2 ('F', 'D')
# pair_choices2 with discarded term : ('D', 'F')
# B
# D
# E
# pair 1 ('B', 'E')
# pair 2 ('F',)
# pair_choices2 with discarded term : ('F',)
# B
# F
# E
# pair 1 ('B', 'E')
# pair 2 ('F', 'G')
# pair_choices2 with discarded term : ('F', 'G')
# B
# F
# E
# pair 1 ('B', 'E')
# pair 2 ('F', 'activity')
# pair_choices2 with discarded term : ('F', 'activity')
# B
# F
# E
# pair 1 ('B', 'E')
# pair 2 ('G', 'A')
# pair_choices2 with discarded term : ('A', 'G')
# B
# A
# E
# pair 1 ('B', 'E')
# pair 2 ('G', 'B')
# pair_choices2 with discarded term : ('G',)
# B
# G
# E
# pair 1 ('B', 'E')
# pair 2 ('G', 'C')
# pair_choices2 with discarded term : ('C', 'G')
# B
# C
# E
# pair 1 ('B', 'E')
# pair 2 ('G', 'D')
# pair_choices2 with discarded term : ('D', 'G')
# B
# D
# E
# pair 1 ('B', 'E')
# pair 2 ('G', 'F')
# pair_choices2 with discarded term : ('F', 'G')
# B
# F
# E
# pair 1 ('B', 'E')
# pair 2 ('G',)
# pair_choices2 with discarded term : ('G',)
# B
# G
# E
# pair 1 ('B', 'E')
# pair 2 ('G', 'activity')
# pair_choices2 with discarded term : ('G', 'activity')
# B
# G
# E
# pair 1 ('B', 'E')
# pair 2 ('H', 'B')
# pair_choices2 with discarded term : ('H',)
# B
# H
# E
# pair 1 ('B', 'E')
# pair 2 ('H', 'C')
# pair_choices2 with discarded term : ('C', 'H')
# B
# C
# E
# pair 1 ('B', 'E')
# pair 2 ('H', 'D')
# pair_choices2 with discarded term : ('D', 'H')
# B
# D
# E
# pair 1 ('B', 'E')
# pair 2 ('H', 'E')
# pair_choices2 with discarded term : ('H',)
# B
# H
# E
# pair 1 ('B', 'E')
# pair 2 ('H',)
# pair_choices2 with discarded term : ('H',)
# B
# H
# E
# pair 1 ('B', 'E')
# pair 2 ('H', 'activity')
# pair_choices2 with discarded term : ('H', 'activity')
# B
# H
# E
# pair 1 ('B', 'E')
# pair 2 ('activity', 'A')
# pair_choices2 with discarded term : ('A', 'activity')
# B
# A
# E
# pair 1 ('B', 'E')
# pair 2 ('activity', 'B')
# pair_choices2 with discarded term : ('activity',)
# B
# activity
# E
# pair 1 ('B', 'E')
# pair 2 ('activity', 'C')
# pair_choices2 with discarded term : ('C', 'activity')
# B
# C
# E
# pair 1 ('B', 'E')
# pair 2 ('activity', 'D')
# pair_choices2 with discarded term : ('D', 'activity')
# B
# D
# E
# pair 1 ('B', 'E')
# pair 2 ('activity', 'E')
# pair_choices2 with discarded term : ('activity',)
# B
# activity
# E
# pair 1 ('B', 'E')
# pair 2 ('activity', 'F')
# ...
# flat_pair2 : ['A', 'B', 'E']
# pair2 : (('A',), ('C', 'E'))
# flat_pair2 : ['A', 'C', 'E']
# pair2 : (('A',), ('D', 'E'))
# flat_pair2 : ['A', 'D', 'E']
# pair2 : (('A',), ('E',))
# flat_pair2 : ['A', 'E']
# pair2 : (('A',), ('E', 'H'))
# flat_pair2 : ['A', 'E', 'H']
# pair2 : (('A',), ('B', 'F'))
# flat_pair2 : ['A', 'B', 'F']
# pair2 : (('A',), ('C', 'F'))
# flat_pair2 : ['A', 'C', 'F']
# pair2 : (('A',), ('D', 'F'))
# flat_pair2 : ['A', 'D', 'F']
# pair2 : (('A',), ('F',))
# flat_pair2 : ['A', 'F']
# pair2 : (('A',), ('B', 'H'))
# flat_pair2 : ['A', 'B', 'H']
# pair2 : (('A',), ('C', 'H'))
# flat_pair2 : ['A', 'C', 'H']
# pair2 : (('A',), ('D', 'H'))
# flat_pair2 : ['A', 'D', 'H']
# pair2 : (('A',), ('E', 'H'))
# flat_pair2 : ['A', 'E', 'H']
# pair2 : (('A',), ('H',))
# flat_pair2 : ['A', 'H']
# pair2 : (('A',), ('B', 'D', 'E'))
# flat_pair2 : ['A', 'B', 'D', 'E']
# pair2 : (('A',), ('B', 'D', 'F'))
# flat_pair2 : ['A', 'B', 'D', 'F']
# pair2 : (('A',), ('B', 'D', 'H'))
# flat_pair2 : ['A', 'B', 'D', 'H']
# pair2 : (('A',), ('B', 'E', 'H'))
# flat_pair2 : ['A', 'B', 'E', 'H']
# pair2 : (('A',), ('C', 'E', 'H'))
# flat_pair2 : ['A', 'C', 'E', 'H']
# pair2 : (('A',), ('D', 'E', 'H'))
# flat_pair2 : ['A', 'D', 'E', 'H']
# pair2 : (('A',), ('B', 'D', 'E', 'H'))
# flat_pair2 : ['A', 'B', 'D', 'E', 'H']
# pair2 : (('A', 'G'), ('H',))
# flat_pair2 : ['A', 'G', 'H']
# pair2 : (('E',), ('F', 'G'))
# flat_pair2 : ['E', 'F', 'G']
# issubset
# pair2 : (('E',), ('F', 'G'))
# flat_pair2 : ['E', 'F', 'G']
# issubset
# pair2 : (('E',), ('G',))
# flat_pair2 : ['E', 'G']
# pair2 : (('G', 'A'), ('H',))
# flat_pair2 : ['G', 'A', 'H']
# pair2 : (('G',), ('H',))
# flat_pair2 : ['G', 'H']
# pair1 : (('E',), ('F', 'G'))
# flat_pair1 : ['E', 'F', 'G']
# pair2 : ('A', 'B')
# flat_pair2 : ['A', 'B']
# pair2 : ('A', 'C')
# flat_pair2 : ['A', 'C']
# pair2 : ('A', 'D')
# flat_pair2 : ['A', 'D']
# pair2 : ('A', 'E')
# flat_pair2 : ['A', 'E']
# pair2 : ('A', 'F')
# flat_pair2 : ['A', 'F']
# pair2 : ('A', 'H')
# flat_pair2 : ['A', 'H']
# pair2 : ('D', 'C')
# flat_pair2 : ['D', 'C']
# pair2 : ('E', 'F')
# flat_pair2 : ['E', 'F']
# pair2 : ('E', 'G')
# flat_pair2 : ['E', 'G']
# pair2 : ('G', 'H')
# flat_pair2 : ['G', 'H']
# pair2 : (('A',), ('B', 'D'))
# flat_pair2 : ['A', 'B', 'D']
# pair2 : (('A',), ('B', 'E'))
# flat_pair2 : ['A', 'B', 'E']
# pair2 : (('A',), ('B', 'F'))
# flat_pair2 : ['A', 'B', 'F']
# pair2 : (('A',), ('B', 'H'))
# flat_pair2 : ['A', 'B', 'H']
# pair2 : (('A',), ('C', 'E'))
# flat_pair2 : ['A', 'C', 'E']
# pair2 : (('A',), ('C', 'F'))
# flat_pair2 : ['A', 'C', 'F']
# pair2 : (('A',), ('C', 'H'))
# flat_pair2 : ['A', 'C', 'H']
# pair2 : (('A',), ('B', 'D'))
# flat_pair2 : ['A', 'B', 'D']
# pair2 : (('A',), ('D',))
# flat_pair2 : ['A', 'D']
# pair2 : (('A',), ('D', 'E'))
# flat_pair2 : ['A', 'D', 'E']
# pair2 : (('A',), ('D', 'F'))
# flat_pair2 : ['A', 'D', 'F']
# pair2 : (('A',), ('D', 'H'))
# flat_pair2 : ['A', 'D', 'H']
# pair2 : (('A',), ('B', 'E'))
# flat_pair2 : ['A', 'B', 'E']
# pair2 : (('A',), ('C', 'E'))
# flat_pair2 : ['A', 'C', 'E']
# pair2 : (('A',), ('D', 'E'))
# flat_pair2 : ['A', 'D', 'E']
# pair2 : (('A',), ('E',))
# flat_pair2 : ['A', 'E']
# pair2 : (('A',), ('E', 'H'))
# flat_pair2 : ['A', 'E', 'H']
# pair2 : (('A',), ('B', 'F'))
# flat_pair2 : ['A', 'B', 'F']
# pair2 : (('A',), ('C', 'F'))
# flat_pair2 : ['A', 'C', 'F']
# pair2 : (('A',), ('D', 'F'))
# flat_pair2 : ['A', 'D', 'F']
# pair2 : (('A',), ('F',))
# flat_pair2 : ['A', 'F']
# pair2 : (('A',), ('B', 'H'))
# flat_pair2 : ['A', 'B', 'H']
# pair2 : (('A',), ('C', 'H'))
# flat_pair2 : ['A', 'C', 'H']
# pair2 : (('A',), ('D', 'H'))
# flat_pair2 : ['A', 'D', 'H']
# pair2 : (('A',), ('E', 'H'))
# flat_pair2 : ['A', 'E', 'H']
# pair2 : (('A',), ('H',))
# flat_pair2 : ['A', 'H']
# pair2 : (('A',), ('B', 'D', 'E'))
# flat_pair2 : ['A', 'B', 'D', 'E']
# pair2 : (('A',), ('B', 'D', 'F'))
# flat_pair2 : ['A', 'B', 'D', 'F']
# pair2 : (('A',), ('B', 'D', 'H'))
# flat_pair2 : ['A', 'B', 'D', 'H']
# pair2 : (('A',), ('B', 'E', 'H'))
# flat_pair2 : ['A', 'B', 'E', 'H']
# pair2 : (('A',), ('C', 'E', 'H'))
# flat_pair2 : ['A', 'C', 'E', 'H']
# pair2 : (('A',), ('D', 'E', 'H'))
# flat_pair2 : ['A', 'D', 'E', 'H']
# pair2 : (('A',), ('B', 'D', 'E', 'H'))
# flat_pair2 : ['A', 'B', 'D', 'E', 'H']
# pair2 : (('A', 'G'), ('H',))
# flat_pair2 : ['A', 'G', 'H']
# pair2 : (('E',), ('F',))
# flat_pair2 : ['E', 'F']
# pair2 : (('E',), ('F', 'G'))
# flat_pair2 : ['E', 'F', 'G']
# pair2 : (('E',), ('G',))
# flat_pair2 : ['E', 'G']
# pair2 : (('G', 'A'), ('H',))
# flat_pair2 : ['G', 'A', 'H']
# pair2 : (('G',), ('H',))
# flat_pair2 : ['G', 'H']
# append
# pair1 : (('E',), ('F', 'G'))
# flat_pair1 : ['E', 'F', 'G']
# pair2 : ('A', 'B')
# flat_pair2 : ['A', 'B']
# pair2 : ('A', 'C')
# flat_pair2 : ['A', 'C']
# pair2 : ('A', 'D')
# flat_pair2 : ['A', 'D']
# pair2 : ('A', 'E')
# flat_pair2 : ['A', 'E']
# pair2 : ('A', 'F')
# flat_pair2 : ['A', 'F']
# pair2 : ('A', 'H')
# flat_pair2 : ['A', 'H']
# pair2 : ('D', 'C')
# flat_pair2 : ['D', 'C']
# pair2 : ('E', 'F')
# flat_pair2 : ['E', 'F']
# pair2 : ('E', 'G')
# flat_pair2 : ['E', 'G']
# pair2 : ('G', 'H')
# flat_pair2 : ['G', 'H']
# pair2 : (('A',), ('B', 'D'))
# flat_pair2 : ['A', 'B', 'D']
# pair2 : (('A',), ('B', 'E'))
# flat_pair2 : ['A', 'B', 'E']
# pair2 : (('A',), ('B', 'F'))
# flat_pair2 : ['A', 'B', 'F']
# pair2 : (('A',), ('B', 'H'))
# flat_pair2 : ['A', 'B', 'H']
# pair2 : (('A',), ('C', 'E'))
# flat_pair2 : ['A', 'C', 'E']
# pair2 : (('A',), ('C', 'F'))
# flat_pair2 : ['A', 'C', 'F']
# pair2 : (('A',), ('C', 'H'))
# flat_pair2 : ['A', 'C', 'H']
# pair2 : (('A',), ('B', 'D'))
# flat_pair2 : ['A', 'B', 'D']
# pair2 : (('A',), ('D',))
# flat_pair2 : ['A', 'D']
# pair2 : (('A',), ('D', 'E'))
# flat_pair2 : ['A', 'D', 'E']
# pair2 : (('A',), ('D', 'F'))
# flat_pair2 : ['A', 'D', 'F']
# pair2 : (('A',), ('D', 'H'))
# flat_pair2 : ['A', 'D', 'H']
# pair2 : (('A',), ('B', 'E'))
# flat_pair2 : ['A', 'B', 'E']
# pair2 : (('A',), ('C', 'E'))
# flat_pair2 : ['A', 'C', 'E']
# pair2 : (('A',), ('D', 'E'))
# flat_pair2 : ['A', 'D', 'E']
# pair2 : (('A',), ('E',))
# flat_pair2 : ['A', 'E']
# pair2 : (('A',), ('E', 'H'))
# flat_pair2 : ['A', 'E', 'H']
# pair2 : (('A',), ('B', 'F'))
# flat_pair2 : ['A', 'B', 'F']
# pair2 : (('A',), ('C', 'F'))
# flat_pair2 : ['A', 'C', 'F']
# pair2 : (('A',), ('D', 'F'))
# flat_pair2 : ['A', 'D', 'F']
# pair2 : (('A',), ('F',))
# flat_pair2 : ['A', 'F']
# pair2 : (('A',), ('B', 'H'))
# flat_pair2 : ['A', 'B', 'H']
# pair2 : (('A',), ('C', 'H'))
# flat_pair2 : ['A', 'C', 'H']
# pair2 : (('A',), ('D', 'H'))
# flat_pair2 : ['A', 'D', 'H']
# pair2 : (('A',), ('E', 'H'))
# flat_pair2 : ['A', 'E', 'H']
# pair2 : (('A',), ('H',))
# flat_pair2 : ['A', 'H']
# pair2 : (('A',), ('B', 'D', 'E'))
# flat_pair2 : ['A', 'B', 'D', 'E']
# pair2 : (('A',), ('B', 'D', 'F'))
# flat_pair2 : ['A', 'B', 'D', 'F']
# pair2 : (('A',), ('B', 'D', 'H'))
# flat_pair2 : ['A', 'B', 'D', 'H']
# pair2 : (('A',), ('B', 'E', 'H'))
# flat_pair2 : ['A', 'B', 'E', 'H']
# pair2 : (('A',), ('C', 'E', 'H'))
# flat_pair2 : ['A', 'C', 'E', 'H']
# pair2 : (('A',), ('D', 'E', 'H'))
# flat_pair2 : ['A', 'D', 'E', 'H']
# pair2 : (('A',), ('B', 'D', 'E', 'H'))
# flat_pair2 : ['A', 'B', 'D', 'E', 'H']
# pair2 : (('A', 'G'), ('H',))
# flat_pair2 : ['A', 'G', 'H']
# pair2 : (('E',), ('F',))
# flat_pair2 : ['E', 'F']
# pair2 : (('E',), ('F', 'G'))
# flat_pair2 : ['E', 'F', 'G']
# pair2 : (('E',), ('G',))
# flat_pair2 : ['E', 'G']
# pair2 : (('G', 'A'), ('H',))
# flat_pair2 : ['G', 'A', 'H']
# pair2 : (('G',), ('H',))
# flat_pair2 : ['G', 'H']
# append
# pair1 : (('E',), ('G',))
# flat_pair1 : ['E', 'G']
# pair2 : ('A', 'B')
# flat_pair2 : ['A', 'B']
# pair2 : ('A', 'C')
# flat_pair2 : ['A', 'C']
# pair2 : ('A', 'D')
# flat_pair2 : ['A', 'D']
# pair2 : ('A', 'E')
# flat_pair2 : ['A', 'E']
# pair2 : ('A', 'F')
# flat_pair2 : ['A', 'F']
# pair2 : ('A', 'H')
# flat_pair2 : ['A', 'H']
# pair2 : ('D', 'C')
# flat_pair2 : ['D', 'C']
# pair2 : ('E', 'F')
# flat_pair2 : ['E', 'F']
# pair2 : ('E', 'G')
# flat_pair2 : ['E', 'G']
# pair2 : ('G', 'H')
# flat_pair2 : ['G', 'H']
# pair2 : (('A',), ('B', 'D'))
# flat_pair2 : ['A', 'B', 'D']
# pair2 : (('A',), ('B', 'E'))
# flat_pair2 : ['A', 'B', 'E']
# pair2 : (('A',), ('B', 'F'))
# flat_pair2 : ['A', 'B', 'F']
# pair2 : (('A',), ('B', 'H'))
# flat_pair2 : ['A', 'B', 'H']
# pair2 : (('A',), ('C', 'E'))
# flat_pair2 : ['A', 'C', 'E']
# pair2 : (('A',), ('C', 'F'))
# flat_pair2 : ['A', 'C', 'F']
# pair2 : (('A',), ('C', 'H'))
# flat_pair2 : ['A', 'C', 'H']
# pair2 : (('A',), ('B', 'D'))
# flat_pair2 : ['A', 'B', 'D']
# pair2 : (('A',), ('D',))
# flat_pair2 : ['A', 'D']
# pair2 : (('A',), ('D', 'E'))
# flat_pair2 : ['A', 'D', 'E']
# pair2 : (('A',), ('D', 'F'))
# flat_pair2 : ['A', 'D', 'F']
# pair2 : (('A',), ('D', 'H'))
# flat_pair2 : ['A', 'D', 'H']
# pair2 : (('A',), ('B', 'E'))
# flat_pair2 : ['A', 'B', 'E']
# pair2 : (('A',), ('C', 'E'))
# flat_pair2 : ['A', 'C', 'E']
# pair2 : (('A',), ('D', 'E'))
# flat_pair2 : ['A', 'D', 'E']
# pair2 : (('A',), ('E',))
# flat_pair2 : ['A', 'E']
# pair2 : (('A',), ('E', 'H'))
# flat_pair2 : ['A', 'E', 'H']
# pair2 : (('A',), ('B', 'F'))
# flat_pair2 : ['A', 'B', 'F']
# pair2 : (('A',), ('C', 'F'))
# flat_pair2 : ['A', 'C', 'F']
# pair2 : (('A',), ('D', 'F'))
# flat_pair2 : ['A', 'D', 'F']
# pair2 : (('A',), ('F',))
# flat_pair2 : ['A', 'F']
# pair2 : (('A',), ('B', 'H'))
# flat_pair2 : ['A', 'B', 'H']
# pair2 : (('A',), ('C', 'H'))
# flat_pair2 : ['A', 'C', 'H']
# pair2 : (('A',), ('D', 'H'))
# flat_pair2 : ['A', 'D', 'H']
# pair2 : (('A',), ('E', 'H'))
# flat_pair2 : ['A', 'E', 'H']
# pair2 : (('A',), ('H',))
# flat_pair2 : ['A', 'H']
# pair2 : (('A',), ('B', 'D', 'E'))
# flat_pair2 : ['A', 'B', 'D', 'E']
# pair2 : (('A',), ('B', 'D', 'F'))
# flat_pair2 : ['A', 'B', 'D', 'F']
# pair2 : (('A',), ('B', 'D', 'H'))
# flat_pair2 : ['A', 'B', 'D', 'H']
# pair2 : (('A',), ('B', 'E', 'H'))
# flat_pair2 : ['A', 'B', 'E', 'H']
# pair2 : (('A',), ('C', 'E', 'H'))
# flat_pair2 : ['A', 'C', 'E', 'H']
# pair2 : (('A',), ('D', 'E', 'H'))
# flat_pair2 : ['A', 'D', 'E', 'H']
# pair2 : (('A',), ('B', 'D', 'E', 'H'))
# flat_pair2 : ['A', 'B', 'D', 'E', 'H']
# pair2 : (('A', 'G'), ('H',))
# flat_pair2 : ['A', 'G', 'H']
# pair2 : (('E',), ('F',))
# flat_pair2 : ['E', 'F']
# pair2 : (('E',), ('F', 'G'))
# flat_pair2 : ['E', 'F', 'G']
# issubset
# pair2 : (('E',), ('F', 'G'))
# flat_pair2 : ['E', 'F', 'G']
# issubset
# pair2 : (('G', 'A'), ('H',))
# flat_pair2 : ['G', 'A', 'H']
# pair2 : (('G',), ('H',))
# flat_pair2 : ['G', 'H']
# pair1 : (('G', 'A'), ('H',))
# flat_pair1 : ['G', 'A', 'H']
# pair2 : ('A', 'B')
# flat_pair2 : ['A', 'B']
# pair2 : ('A', 'C')
# flat_pair2 : ['A', 'C']
# pair2 : ('A', 'D')
# flat_pair2 : ['A', 'D']
# pair2 : ('A', 'E')
# flat_pair2 : ['A', 'E']
# pair2 : ('A', 'F')
# flat_pair2 : ['A', 'F']
# pair2 : ('A', 'H')
# flat_pair2 : ['A', 'H']
# pair2 : ('D', 'C')
# flat_pair2 : ['D', 'C']
# pair2 : ('E', 'F')
# flat_pair2 : ['E', 'F']
# pair2 : ('E', 'G')
# flat_pair2 : ['E', 'G']
# pair2 : ('G', 'H')
# flat_pair2 : ['G', 'H']
# pair2 : (('A',), ('B', 'D'))
# flat_pair2 : ['A', 'B', 'D']
# pair2 : (('A',), ('B', 'E'))
# flat_pair2 : ['A', 'B', 'E']
# pair2 : (('A',), ('B', 'F'))
# flat_pair2 : ['A', 'B', 'F']
# pair2 : (('A',), ('B', 'H'))
# flat_pair2 : ['A', 'B', 'H']
# pair2 : (('A',), ('C', 'E'))
# flat_pair2 : ['A', 'C', 'E']
# pair2 : (('A',), ('C', 'F'))
# flat_pair2 : ['A', 'C', 'F']
# pair2 : (('A',), ('C', 'H'))
# flat_pair2 : ['A', 'C', 'H']
# pair2 : (('A',), ('B', 'D'))
# flat_pair2 : ['A', 'B', 'D']
# pair2 : (('A',), ('D',))
# flat_pair2 : ['A', 'D']
# pair2 : (('A',), ('D', 'E'))
# flat_pair2 : ['A', 'D', 'E']
# pair2 : (('A',), ('D', 'F'))
# flat_pair2 : ['A', 'D', 'F']
# pair2 : (('A',), ('D', 'H'))
# flat_pair2 : ['A', 'D', 'H']
# pair2 : (('A',), ('B', 'E'))
# flat_pair2 : ['A', 'B', 'E']
# pair2 : (('A',), ('C', 'E'))
# flat_pair2 : ['A', 'C', 'E']
# pair2 : (('A',), ('D', 'E'))
# flat_pair2 : ['A', 'D', 'E']
# pair2 : (('A',), ('E',))
# flat_pair2 : ['A', 'E']
# pair2 : (('A',), ('E', 'H'))
# flat_pair2 : ['A', 'E', 'H']
# pair2 : (('A',), ('B', 'F'))
# flat_pair2 : ['A', 'B', 'F']
# pair2 : (('A',), ('C', 'F'))
# flat_pair2 : ['A', 'C', 'F']
# pair2 : (('A',), ('D', 'F'))
# flat_pair2 : ['A', 'D', 'F']
# pair2 : (('A',), ('F',))
# flat_pair2 : ['A', 'F']
# pair2 : (('A',), ('B', 'H'))
# flat_pair2 : ['A', 'B', 'H']
# pair2 : (('A',), ('C', 'H'))
# flat_pair2 : ['A', 'C', 'H']
# pair2 : (('A',), ('D', 'H'))
# flat_pair2 : ['A', 'D', 'H']
# pair2 : (('A',), ('E', 'H'))
# flat_pair2 : ['A', 'E', 'H']
# pair2 : (('A',), ('H',))
# flat_pair2 : ['A', 'H']
# pair2 : (('A',), ('B', 'D', 'E'))
# flat_pair2 : ['A', 'B', 'D', 'E']
# pair2 : (('A',), ('B', 'D', 'F'))
# flat_pair2 : ['A', 'B', 'D', 'F']
# pair2 : (('A',), ('B', 'D', 'H'))
# flat_pair2 : ['A', 'B', 'D', 'H']
# pair2 : (('A',), ('B', 'E', 'H'))
# flat_pair2 : ['A', 'B', 'E', 'H']
# pair2 : (('A',), ('C', 'E', 'H'))
# flat_pair2 : ['A', 'C', 'E', 'H']
# pair2 : (('A',), ('D', 'E', 'H'))
# flat_pair2 : ['A', 'D', 'E', 'H']
# pair2 : (('A',), ('B', 'D', 'E', 'H'))
# flat_pair2 : ['A', 'B', 'D', 'E', 'H']
# pair2 : (('A', 'G'), ('H',))
# flat_pair2 : ['A', 'G', 'H']
# pair2 : (('E',), ('F',))
# flat_pair2 : ['E', 'F']
# pair2 : (('E',), ('F', 'G'))
# flat_pair2 : ['E', 'F', 'G']
# pair2 : (('E',), ('F', 'G'))
# flat_pair2 : ['E', 'F', 'G']
# pair2 : (('E',), ('G',))
# flat_pair2 : ['E', 'G']
# pair2 : (('G',), ('H',))
# flat_pair2 : ['G', 'H']
# append
# pair1 : (('G',), ('H',))
# flat_pair1 : ['G', 'H']
# pair2 : ('A', 'B')
# flat_pair2 : ['A', 'B']
# pair2 : ('A', 'C')
# flat_pair2 : ['A', 'C']
# pair2 : ('A', 'D')
# flat_pair2 : ['A', 'D']
# pair2 : ('A', 'E')
# flat_pair2 : ['A', 'E']
# pair2 : ('A', 'F')
# flat_pair2 : ['A', 'F']
# pair2 : ('A', 'H')
# flat_pair2 : ['A', 'H']
# pair2 : ('D', 'C')
# flat_pair2 : ['D', 'C']
# pair2 : ('E', 'F')
# flat_pair2 : ['E', 'F']
# pair2 : ('E', 'G')
# flat_pair2 : ['E', 'G']
# pair2 : ('G', 'H')
# flat_pair2 : ['G', 'H']
# pair2 : (('A',), ('B', 'D'))
# flat_pair2 : ['A', 'B', 'D']
# pair2 : (('A',), ('B', 'E'))
# flat_pair2 : ['A', 'B', 'E']
# pair2 : (('A',), ('B', 'F'))
# flat_pair2 : ['A', 'B', 'F']
# pair2 : (('A',), ('B', 'H'))
# flat_pair2 : ['A', 'B', 'H']
# pair2 : (('A',), ('C', 'E'))
# flat_pair2 : ['A', 'C', 'E']
# pair2 : (('A',), ('C', 'F'))
# flat_pair2 : ['A', 'C', 'F']
# pair2 : (('A',), ('C', 'H'))
# flat_pair2 : ['A', 'C', 'H']
# pair2 : (('A',), ('B', 'D'))
# flat_pair2 : ['A', 'B', 'D']
# pair2 : (('A',), ('D',))
# flat_pair2 : ['A', 'D']
# pair2 : (('A',), ('D', 'E'))
# flat_pair2 : ['A', 'D', 'E']
# pair2 : (('A',), ('D', 'F'))
# flat_pair2 : ['A', 'D', 'F']
# pair2 : (('A',), ('D', 'H'))
# flat_pair2 : ['A', 'D', 'H']
# pair2 : (('A',), ('B', 'E'))
# flat_pair2 : ['A', 'B', 'E']
# pair2 : (('A',), ('C', 'E'))
# flat_pair2 : ['A', 'C', 'E']
# pair2 : (('A',), ('D', 'E'))
# flat_pair2 : ['A', 'D', 'E']
# pair2 : (('A',), ('E',))
# flat_pair2 : ['A', 'E']
# pair2 : (('A',), ('E', 'H'))
# flat_pair2 : ['A', 'E', 'H']
# pair2 : (('A',), ('B', 'F'))
# flat_pair2 : ['A', 'B', 'F']
# pair2 : (('A',), ('C', 'F'))
# flat_pair2 : ['A', 'C', 'F']
# pair2 : (('A',), ('D', 'F'))
# flat_pair2 : ['A', 'D', 'F']
# pair2 : (('A',), ('F',))
# flat_pair2 : ['A', 'F']
# pair2 : (('A',), ('B', 'H'))
# flat_pair2 : ['A', 'B', 'H']
# pair2 : (('A',), ('C', 'H'))
# flat_pair2 : ['A', 'C', 'H']
# pair2 : (('A',), ('D', 'H'))
# flat_pair2 : ['A', 'D', 'H']
# pair2 : (('A',), ('E', 'H'))
# flat_pair2 : ['A', 'E', 'H']
# pair2 : (('A',), ('H',))
# flat_pair2 : ['A', 'H']
# pair2 : (('A',), ('B', 'D', 'E'))
# flat_pair2 : ['A', 'B', 'D', 'E']
# pair2 : (('A',), ('B', 'D', 'F'))
# flat_pair2 : ['A', 'B', 'D', 'F']
# pair2 : (('A',), ('B', 'D', 'H'))
# flat_pair2 : ['A', 'B', 'D', 'H']
# pair2 : (('A',), ('B', 'E', 'H'))
# flat_pair2 : ['A', 'B', 'E', 'H']
# pair2 : (('A',), ('C', 'E', 'H'))
# flat_pair2 : ['A', 'C', 'E', 'H']
# pair2 : (('A',), ('D', 'E', 'H'))
# flat_pair2 : ['A', 'D', 'E', 'H']
# pair2 : (('A',), ('B', 'D', 'E', 'H'))
# flat_pair2 : ['A', 'B', 'D', 'E', 'H']
# pair2 : (('A', 'G'), ('H',))
# flat_pair2 : ['A', 'G', 'H']
# issubset
# pair2 : (('E',), ('F',))
# flat_pair2 : ['E', 'F']
# pair2 : (('E',), ('F', 'G'))
# flat_pair2 : ['E', 'F', 'G']
# pair2 : (('E',), ('F', 'G'))
# flat_pair2 : ['E', 'F', 'G']
# pair2 : (('E',), ('G',))
# flat_pair2 : ['E', 'G']
# pair2 : (('G', 'A'), ('H',))
# flat_pair2 : ['G', 'A', 'H']
# issubset
# [('D', 'C'), (('A',), ('C', 'F')), (('A',), ('B', 'D', 'F')), (('A',), ('C', 'E', 'H')), (('A',), ('B', 'D', 'E', 'H')), (('A', 'G'), ('H',)), (('E',), ('F', 'G'))]
# [('P0', SortedSet(['A', 'activity'], key=None, load=1000)), ('D', 'P1', 'C'), (('A',), 'P2', ('C', 'F')), (('A',), 'P3', ('B', 'D', 'F')), (('A',), 'P4', ('C', 'E', 'H')), (('A',), 'P5', ('B', 'D', 'E', 'H')), (('A', 'G'), 'P6', ('H',)), (('E',), 'P7', ('F', 'G')), (SortedSet(['B', 'C', 'D', 'F', 'H', 'activity'], key=None, load=1000), 'P8')]

# %%
print(Alph.traces)
# Out:
# SortedDict(None, 1000, {'1': ['A', 'B', 'C'], '10': ['A', 'H', 'F'], '11': ['A', 'B', 'B', 'C'], '12': ['A', 'D', 'C', 'C'], '13': ['A', 'B', 'C', 'B', 'C'], '2': ['A', 'D', 'C'], '3': ['A', 'E', 'F', 'H'], '4': ['A', 'E', 'G', 'H'], '5': ['A', 'C', 'B'], '6': ['A', 'C', 'D'], '7': ['A', 'F'], '8': ['A', 'E', 'F'], '9': ['A', 'E', 'F'], 'case': ['activity']})

# %%
print(Alph.pairs)
# Out:
# [('A', 'B'), ('A', 'C'), ('A', 'D'), ('A', 'E'), ('A', 'F'), ('A', 'H'), ('D', 'C'), ('E', 'F'), ('E', 'G'), ('G', 'H'), (('A',), ('B', 'D')), (('A',), ('B', 'E')), (('A',), ('B', 'F')), (('A',), ('B', 'H')), (('A',), ('C', 'E')), (('A',), ('C', 'F')), (('A',), ('C', 'H')), (('A',), ('B', 'D')), (('A',), ('D',)), (('A',), ('D', 'E')), (('A',), ('D', 'F')), (('A',), ('D', 'H')), (('A',), ('B', 'E')), (('A',), ('C', 'E')), (('A',), ('D', 'E')), (('A',), ('E',)), (('A',), ('E', 'H')), (('A',), ('B', 'F')), (('A',), ('C', 'F')), (('A',), ('D', 'F')), (('A',), ('F',)), (('A',), ('B', 'H')), (('A',), ('C', 'H')), (('A',), ('D', 'H')), (('A',), ('E', 'H')), (('A',), ('H',)), (('A',), ('B', 'D', 'E')), (('A',), ('B', 'D', 'F')), (('A',), ('B', 'D', 'H')), (('A',), ('B', 'E', 'H')), (('A',), ('C', 'E', 'H')), (('A',), ('D', 'E', 'H')), (('A',), ('B', 'D', 'E', 'H')), (('A', 'G'), ('H',)), (('E',), ('F',)), (('E',), ('F', 'G')), (('E',), ('F', 'G')), (('E',), ('G',)), (('G', 'A'), ('H',)), (('G',), ('H',))]

# %%
print(Alph.maxi_pairs)
# Out:
# [('D', 'C'), (('A',), ('C', 'F')), (('A',), ('B', 'D', 'F')), (('A',), ('C', 'E', 'H')), (('A',), ('B', 'D', 'E', 'H')), (('A', 'G'), ('H',)), (('E',), ('F', 'G'))]

# %%
Alph.extract_PetriNet()
#Alph.show(model = "petrinet")
Image('modules/,net-with-colors.png')
# Out:
# SortedSet(['A', 'activity'], key=None, load=1000)

# %%
#Now let's look at Alpha Plus
from modules.process_mining import alpha_plus 

plus = alpha_plus.Alpha_plus(traces)

plus.getInitialTransitions()
plus.getFinalTransitions()
plus.getTransitions()
plus.extractRelations()

plus.computePairs()
plus.extract_maximal_pairs()
plus.add_places()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-1a1c86c15f52> in <module>()
#       2 from modules.process_mining import alpha_plus
#       3
# ----> 4 plus = alpha_plus.Alpha_plus(Alph,traces)
#       5
#       6 plus.getInitialTransitions()
#
# TypeError: __init__() takes 2 positional arguments but 3 were given

# %%
plus.extract_PetriNet()
plus.show(model = "petrinet")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-56741acb48ef> in <module>()
# ----> 1 plus.extract_PetriNet()
#       2 plus.show(model = "petrinet")
#
# ~\Documents\Learning-projects\modules\process_mining\alpha_plus.py in extract_PetriNet(self)
#     159         self.alphaObject = Alph
#     160     def extract_PetriNet(self):
# --> 161         for transition in self.L1L:
#     162             self.alphaObject.PetriNet.add_transition(Transition(transition))
#     163         for element in self.F_L1L:
#
# TypeError: 'NoneType' object is not iterable

# %%
pd.DataFrame.from_dict(plus.relations, orient="index")
# Out:
#                                  A                          B  \
# A                Relations.CHOICES  Relations.RIGHT_CAUSALITY
# B         Relations.LEFT_CAUSALITY  Relations.RIGHT_CAUSALITY
# C         Relations.LEFT_CAUSALITY         Relations.PARALLEL
# D         Relations.LEFT_CAUSALITY          Relations.CHOICES
# E         Relations.LEFT_CAUSALITY          Relations.CHOICES
# F         Relations.LEFT_CAUSALITY          Relations.CHOICES
# G                Relations.CHOICES          Relations.CHOICES
# H         Relations.LEFT_CAUSALITY          Relations.CHOICES
# activity         Relations.CHOICES          Relations.CHOICES
#
#                                   C                          D  \
# A         Relations.RIGHT_CAUSALITY  Relations.RIGHT_CAUSALITY
# B                Relations.PARALLEL          Relations.CHOICES
# C         Relations.RIGHT_CAUSALITY         Relations.PARALLEL
# D                Relations.PARALLEL          Relations.CHOICES
# E                 Relations.CHOICES          Relations.CHOICES
# F                 Relations.CHOICES          Relations.CHOICES
# G                 Relations.CHOICES          Relations.CHOICES
# H                 Relations.CHOICES          Relations.CHOICES
# activity          Relations.CHOICES          Relations.CHOICES
#
#                                   E                          F  \
# A         Relations.RIGHT_CAUSALITY  Relations.RIGHT_CAUSALITY
# B                 Relations.CHOICES          Relations.CHOICES
# C                 Relations.CHOICES          Relations.CHOICES
# D                 Relations.CHOICES          Relations.CHOICES
# E                 Relations.CHOICES  Relations.RIGHT_CAUSALITY
# F          Relations.LEFT_CAUSALITY          Relations.CHOICES
# G          Relations.LEFT_CAUSALITY          Relations.CHOICES
# H                 Relations.CHOICES         Relations.PARALLEL
# activity          Relations.CHOICES          Relations.CHOICES
#
#                                   G                          H  \
# A                 Relations.CHOICES  Relations.RIGHT_CAUSALITY
# B                 Relations.CHOICES          Relations.CHOICES
# C                 Relations.CHOICES          Relations.CHOICES
# D                 Relations.CHOICES          Relations.CHOICES
# E         Relations.RIGHT_CAUSALITY          Relations.CHOICES
# F                 Relations.CHOICES         Relations.PARALLEL
# G                 Relations.CHOICES  Relations.RIGHT_CAUSALITY
# H          Relations.LEFT_CAUSALITY          Relations.CHOICES
# activity          Relations.CHOICES          Relations.CHOICES
#
#                    activity
# A         Relations.CHOICES
# B         Relations.CHOICES
# C         Relations.CHOICES
# D         Relations.CHOICES
# E         Relations.CHOICES
# F         Relations.CHOICES
# G         Relations.CHOICES
# H         Relations.CHOICES
# activity  Relations.CHOICES

# %%
pd.DataFrame.from_dict(Alph.relations, orient="index")
# Out:
#                                  A                          B  \
# A                Relations.CHOICES  Relations.RIGHT_CAUSALITY
# B         Relations.LEFT_CAUSALITY         Relations.PARALLEL
# C         Relations.LEFT_CAUSALITY         Relations.PARALLEL
# D         Relations.LEFT_CAUSALITY          Relations.CHOICES
# E         Relations.LEFT_CAUSALITY          Relations.CHOICES
# F         Relations.LEFT_CAUSALITY          Relations.CHOICES
# G                Relations.CHOICES          Relations.CHOICES
# H         Relations.LEFT_CAUSALITY          Relations.CHOICES
# activity         Relations.CHOICES          Relations.CHOICES
#
#                                   C                          D  \
# A         Relations.RIGHT_CAUSALITY  Relations.RIGHT_CAUSALITY
# B          Relations.LEFT_CAUSALITY          Relations.CHOICES
# C                Relations.PARALLEL   Relations.LEFT_CAUSALITY
# D         Relations.RIGHT_CAUSALITY          Relations.CHOICES
# E                 Relations.CHOICES          Relations.CHOICES
# F                 Relations.CHOICES          Relations.CHOICES
# G                 Relations.CHOICES          Relations.CHOICES
# H                 Relations.CHOICES          Relations.CHOICES
# activity          Relations.CHOICES          Relations.CHOICES
#
#                                   E                          F  \
# A         Relations.RIGHT_CAUSALITY  Relations.RIGHT_CAUSALITY
# B                 Relations.CHOICES          Relations.CHOICES
# C                 Relations.CHOICES          Relations.CHOICES
# D                 Relations.CHOICES          Relations.CHOICES
# E                 Relations.CHOICES  Relations.RIGHT_CAUSALITY
# F          Relations.LEFT_CAUSALITY          Relations.CHOICES
# G          Relations.LEFT_CAUSALITY          Relations.CHOICES
# H                 Relations.CHOICES         Relations.PARALLEL
# activity          Relations.CHOICES          Relations.CHOICES
#
#                                   G                          H  \
# A                 Relations.CHOICES  Relations.RIGHT_CAUSALITY
# B                 Relations.CHOICES          Relations.CHOICES
# C                 Relations.CHOICES          Relations.CHOICES
# D                 Relations.CHOICES          Relations.CHOICES
# E         Relations.RIGHT_CAUSALITY          Relations.CHOICES
# F                 Relations.CHOICES         Relations.PARALLEL
# G                 Relations.CHOICES  Relations.RIGHT_CAUSALITY
# H          Relations.LEFT_CAUSALITY          Relations.CHOICES
# activity          Relations.CHOICES          Relations.CHOICES
#
#                    activity
# A         Relations.CHOICES
# B         Relations.CHOICES
# C         Relations.CHOICES
# D         Relations.CHOICES
# E         Relations.CHOICES
# F         Relations.CHOICES
# G         Relations.CHOICES
# H         Relations.CHOICES
# activity  Relations.CHOICES
